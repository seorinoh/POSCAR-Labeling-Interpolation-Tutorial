# %%
# 현재 작업 디렉터리 확인
# %pwd
# Out:
# 'c:\\Users\\osr11\\OneDrive\\바탕 화면\\interpolation-0_Pmma'

# %%
# 디렉터리 내 파일 목록 확인
import os
file_list = os.listdir()
file_list
# Out:
# ['0_Pmma.vasp', '1_Pmc21.vasp', 'path1.ipynb']

# %%
# .vasp로 끝나는 파일들만 poscar_files로 지정하고 확인
import glob
poscar_files = glob.glob("./*.vasp")
poscar_files
# Out:
# ['.\\0_Pmma.vasp', '.\\1_Pmc21.vasp']

# %%
# initial POSCAR file parsing

# poscar_files들 중 poscar_initial 파일을 지정(1_Pmc21.vasp를 poscar_initial 파일로 함.)
poscar_initial = poscar_files[1]
print(poscar_initial)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_initial_lines = open(poscar_initial, 'r')
initial_lines = read_initial_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
initial_title = initial_lines[0].strip()
print(initial_title)


# 스케일 팩터
initial_scale = float(initial_lines[1].strip())
print(initial_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
initial_lattice = []

for i in range(2,5):
    lattice_row_list = initial_lines[i].split()     #lattice_row_list = [a,b,c]의 리스트

    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))  

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성           
    initial_lattice.append(lattice_row)             

print(initial_lattice[0])
print(initial_lattice[1])
print(initial_lattice[2])


# 각 원자의 종류
initial_atom_types = initial_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나누고 각각 정수화 시켜 list로 만들기)
initial_atom_counts = []

initial_atom_counts_list = initial_lines[6].split()

for part in initial_atom_counts_list:
    initial_atom_counts.append(int(part))

print(initial_atom_counts)
print(type(initial_atom_counts[0]))


# 원자들 총 개수
initial_atoms_total = sum(initial_atom_counts)
print(initial_atoms_total)


# 원자 좌표의 형식
initial_coord_type = initial_lines[7].strip()
print(initial_coord_type)


# 각 atom들 좌표
initial_coords = []

for i in range(8,64):
    coords_row_list = initial_lines[i].split()      #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part))   
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 56개 리스트로 만들어서 전체 실수화 coord 리스트 완성           
    initial_coords.append(coords_row)         

print(initial_coords[0])
print(initial_coords[1])
print(initial_coords[2])
# Out:
# .\1_Pmc21.vasp
# Nd Ca Fe  O
# 1.0
# [5.6095247269, 0.0, 0.0]
# [0.0, 22.5286846161, 0.0]
# [0.0, 0.0, 5.5764307976]
# [4, 8, 12, 32]
# <class 'int'>
# 56
# Direct
# [0.186319526, -0.0, 0.234546979]
# [0.186319526, 0.499999661, 0.234546979]
# [0.686319547, -0.0, 0.765452978]

# %%
# final POSCAR file parsing

# poscar_files들 중 poscar_final 파일을 지정 (0_Pmma.vasp를 poscar_final 파일로 함.)
poscar_final = poscar_files[0]
print(poscar_final)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_final_lines = open(poscar_final, 'r')
final_lines = read_final_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
final_title = final_lines[0].strip()
print(final_title)


# 스케일 팩터
final_scale = float(final_lines[1].strip())
print(final_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
final_lattice = []

for i in range(2,5):
    lattice_row_list = final_lines[i].split()           #lattice_row_list = [a,b,c]의 리스트
    
    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성    
    final_lattice.append(lattice_row) 

print(final_lattice[0])
print(final_lattice[1])
print(final_lattice[2])


# 각 원자의 종류
final_atom_types = final_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나눠서 각각 정수화 시켜 list로 만들기)
final_atom_counts = []
final_atom_counts_list = final_lines[6].split()

for part in final_atom_counts_list:
    final_atom_counts.append(int(part))
    
print(final_atom_counts)
print(type(final_atom_counts[0]))


# 원자들 총 개수
final_atoms_total = sum(final_atom_counts)
print(final_atoms_total)


# 원자 좌표의 형식
final_coord_type = final_lines[7].strip()
print(final_coord_type)


# 각 atom들 좌표
final_coords = []

for i in range(8,64):
    coords_row_list = final_lines[i].split() #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part)) 
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 56개 리스트로 만들어서 전체 실수화 coord 리스트 완성 
    final_coords.append(coords_row) 

print(final_coords[0])
print(final_coords[1])
print(final_coords[2])
# Out:
# .\0_Pmma.vasp
# Nd Ca Fe  O
# 1.0
# [5.5798778534, 0.0, 0.0]
# [0.0, 22.6841869354, 0.0]
# [0.0, 0.0, 5.5896039009]
# [4, 8, 12, 32]
# <class 'int'>
# 56
# Direct
# [0.25, -0.0, 0.232330652]
# [0.25, 0.5, 0.232330652]
# [0.75, -0.0, 0.767669327]

# %%
# Atom Labeling 


# 루트 연산을 위한 math, numpy 모듈
from math import sqrt
import numpy as np


# 재정렬된 코드/ 측정된 거리 넣을 빈 리스트
reordered_coords=[]
measured_distance = []

# base_atom_num: 기준이 되는 initial 원자 번호(순서)
for base_atom_num in range(initial_atoms_total):

    row_measured_distance = []

    # target_atom_num: initial 하나의 원자 기준으로 비교하는 final 원자 번호(순서)
    for target_atom_num in range(final_atoms_total):

        new_distance_difference = []

        # initial과 final 원자의 좌표 한개씩 꺼내기
        for i_c, f_c in zip(initial_coords[base_atom_num], final_coords[target_atom_num]):
            # 원자 좌표 차이
            distance_difference = np.subtract (i_c, f_c)
            # 좌표 차이 반올림
            difference_round = np.round(distance_difference)
            # pbc 고려된 좌표 차이
            new_distance_difference.append(distance_difference - difference_round)

        # 행렬 곱셈하기 위해 벡터를 행렬로 바꾸기
        new_distance_difference = np.array(new_distance_difference)
        lattice = np.array(initial_lattice)
        # 실제 거리를 반영한 원자 좌표 차이
        real_distance = new_distance_difference @ lattice

        # 각 좌표 차이 제곱의 합
        total = real_distance[0]**2 + real_distance[1]**2 + real_distance[2]**2
        # 최종 루트 씌우기(거리 공식)
        distance = sqrt(total)
        row_measured_distance.append(distance)

    # 계산한 실제 거리 저장 
    measured_distance.append(row_measured_distance)

# a: initial 원자의 순서
for a in range (initial_atoms_total):
    # atom_distance: initial 원자 하나에 대한 final 원자 56개와의 거리 리스트
    atom_distance = measured_distance[a]
    # list 중 가장 작은 값 확인
    min_distance = min(atom_distance)
    # 가장 작은 값 인덱스 확인
    min_distance_index = atom_distance.index(min_distance)
    # 인덱스 값 정수화
    min_index = int(min_distance_index)
    # 거리 차이가 가장 작은 값의 코드를 reordered_coords에 정렬
    reordered_coords.append(final_coords[min_index])


print(reordered_coords)
print(len(reordered_coords))
print(reordered_coords[0])
print(reordered_coords[1])
print(reordered_coords[2])
print(reordered_coords[3])
# Out:
# [[0.25, -0.0, 0.232330652], [0.25, 0.5, 0.232330652], [0.75, -0.0, 0.767669327], [0.75, 0.5, 0.767669327], [0.25, 0.3384533, 0.265420356], [0.25, 0.838453089, 0.265422275], [0.75, 0.161546932, 0.734577725], [0.75, 0.6615467, 0.734579687], [0.25, 0.161546711, 0.265420356], [0.25, 0.661546953, 0.265422275], [0.75, 0.338453047, 0.734577725], [0.75, 0.838453258, 0.734579687], [0.25, 0.086420305, 0.746812749], [0.25, 0.586417383, 0.746808995], [0.75, 0.413582659, 0.253190962], [0.75, 0.913579674, 0.253187272], [0.25, 0.413579716, 0.746812749], [0.25, 0.913582617, 0.746808995], [0.75, 0.086417362, 0.253190962], [0.75, 0.586420368, 0.253187272], [0.25, 0.25, 0.727858707], [0.25, 0.749999979, 0.727876878], [0.75, 0.25, 0.272123058], [0.75, 0.749999979, 0.272141314], [0.0, 0.394939749, 0.500000256], [-0.0, 0.894939707, 0.499999744], [-0.0, 0.105060251, 0.500000256], [-0.0, 0.605060209, 0.499999744], [0.499999915, 0.105060251, 0.500000256], [0.500000043, 0.605060209, 0.499999744], [0.499999915, 0.394939749, 0.500000256], [0.500000043, 0.894939707, 0.499999744], [-0.0, 0.066803323, 0.0], [0.0, 0.566803318, 0.0], [-0.0, 0.43319664, 0.0], [0.0, 0.933196682, 0.0], [0.499999744, 0.43319664, 0.0], [0.500000256, 0.933196682, 0.0], [0.499999744, 0.066803323, 0.0], [0.500000256, 0.566803318, 0.0], [0.999997693, 0.25, 0.499996033], [2.334e-06, 0.749999979, 0.500004009], [0.500002307, 0.25, 0.499996033], [0.49999765, 0.749999979, 0.500004009], [0.25, 0.0, 0.649300744], [0.25, 0.499999453, 0.649300744], [0.75, -0.0, 0.350699256], [0.75, 0.500000547, 0.350699256], [0.25, 0.324221854, 0.866900882], [0.25, 0.824222926, 0.866903783], [0.75, 0.175777053, 0.133096185], [0.75, 0.675778167, 0.133099128], [0.25, 0.175778146, 0.866900882], [0.25, 0.675777074, 0.866903783], [0.75, 0.324222947, 0.133096185], [0.75, 0.824221833, 0.133099128]]
# 56
# [0.25, -0.0, 0.232330652]
# [0.25, 0.5, 0.232330652]
# [0.75, -0.0, 0.767669327]
# [0.75, 0.5, 0.767669327]

# %%
# labeling해서 재정렬 된 파일 저장

# 파일 이름 설정하고 쓰기 모드로 열기
filename = f"0_Pmma_reordered.vasp"
with open(filename, 'w') as f:
      
    # 원자 이름 적기
    f.write(f"{final_title}\n")
    # 스케일 벡터 적기
    f.write(f"{final_scale}\n")
    # 라티스 벡터 한줄씩 적기
    for vec in final_lattice:
            f.write("  " + "  ".join(f"{x:.10f}" for x in vec) + "\n")
    # 원자 종류 적기
    f.write("  " + "  ".join(final_atom_types) + "\n")
    # 원자 종류별 갯수 적기
    f.write("  " + "  ".join(str(count) for count in final_atom_counts) + "\n")
    # 좌표 형식 적기
    f.write(f"{final_coord_type.capitalize()}\n")
    # 원자 좌표 한줄씩 적기
    for coord in reordered_coords:
        f.write("  " + "  ".join(f"{x:.10f}" for x in coord) + "\n")

    print("저장됨:", filename)

# 저장된 파일 열어서 확인
filename = f"0_Pmma_reordered.vasp"
with open (filename, 'r') as f:
    content = f.read()

print(content)
# Out:
# 저장됨: 0_Pmma_reordered.vasp
# Nd Ca Fe  O
# 1.0
#   5.5798778534  0.0000000000  0.0000000000
#   0.0000000000  22.6841869354  0.0000000000
#   0.0000000000  0.0000000000  5.5896039009
#   Nd  Ca  Fe  O
#   4  8  12  32
# Direct
#   0.2500000000  -0.0000000000  0.2323306520
#   0.2500000000  0.5000000000  0.2323306520
#   0.7500000000  -0.0000000000  0.7676693270
#   0.7500000000  0.5000000000  0.7676693270
#   0.2500000000  0.3384533000  0.2654203560
#   0.2500000000  0.8384530890  0.2654222750
#   0.7500000000  0.1615469320  0.7345777250
#   0.7500000000  0.6615467000  0.7345796870
#   0.2500000000  0.1615467110  0.2654203560
#   0.2500000000  0.6615469530  0.2654222750
#   0.7500000000  0.3384530470  0.7345777250
#   0.7500000000  0.8384532580  0.7345796870
#   0.2500000000  0.0864203050  0.7468127490
#   0.2500000000  0.5864173830  0.7468089950
#   0.7500000000  0.4135826590  0.2531909620
#   0.7500000000  0.9135796740  0.2531872720
#   0.2500000000  0.4135797160  0.7468127490
#   0.2500000000  0.9135826170  0.7468089950
#   0.7500000000  0.0864173620  0.2531909620
#   0.7500000000  0.5864203680  0.2531872720
#   0.2500000000  0.2500000000  0.7278587070
#   0.2500000000  0.7499999790  0.7278768780
#   0.7500000000  0.2500000000  0.2721230580
#   0.7500000000  0.7499999790  0.2721413140
#   0.0000000000  0.3949397490  0.5000002560
#   -0.0000000000  0.8949397070  0.4999997440
#   -0.0000000000  0.1050602510  0.5000002560
#   -0.0000000000  0.6050602090  0.4999997440
#   0.4999999150  0.1050602510  0.5000002560
#   0.5000000430  0.6050602090  0.4999997440
#   0.4999999150  0.3949397490  0.5000002560
#   0.5000000430  0.8949397070  0.4999997440
#   -0.0000000000  0.0668033230  0.0000000000
#   0.0000000000  0.5668033180  0.0000000000
#   -0.0000000000  0.4331966400  0.0000000000
#   0.0000000000  0.9331966820  0.0000000000
#   0.4999997440  0.4331966400  0.0000000000
#   0.5000002560  0.9331966820  0.0000000000
#   0.4999997440  0.0668033230  0.0000000000
#   0.5000002560  0.5668033180  0.0000000000
#   0.9999976930  0.2500000000  0.4999960330
#   0.0000023340  0.7499999790  0.5000040090
#   0.5000023070  0.2500000000  0.4999960330
#   0.4999976500  0.7499999790  0.5000040090
#   0.2500000000  0.0000000000  0.6493007440
#   0.2500000000  0.4999994530  0.6493007440
#   0.7500000000  -0.0000000000  0.3506992560
#   0.7500000000  0.5000005470  0.3506992560
#   0.2500000000  0.3242218540  0.8669008820
#   0.2500000000  0.8242229260  0.8669037830
#   0.7500000000  0.1757770530  0.1330961850
#   0.7500000000  0.6757781670  0.1330991280
#   0.2500000000  0.1757781460  0.8669008820
#   0.2500000000  0.6757770740  0.8669037830
#   0.7500000000  0.3242229470  0.1330961850
#   0.7500000000  0.8242218330  0.1330991280

# %%
# (interpolation)선형 보간하는 함수 정의

import numpy as np
# 선형 보간된 구조 lattice vector와 atom 좌표 
interpolated_structures = []

# n개의 중간 과정 만들기
n_steps = 15                           # 중간 과정 개수
for step in range(1, n_steps + 1):     #중간 과정 위치 (1부터 n_steps까지)
   

    # 보간 상수 x (중간 과정 위치 나타냄)
    # x는 곱해주는 비율(중간 과정을 3개로 만들면, 중간과정 1번 x=0.25/ 중간과정 2번 x=0.5/ 중간과정 3번 x=0.75)
    x = step / (n_steps + 1) 


    # lattice vector interpolation

    # 라티스 벡터 보간 후 중간 과정 벡터 저장할 빈 리스트
    intermediate_lattice = []

    # 3x3 라티스 벡터를 한 줄씩 지정
    for vec_initial, vec_final in zip(initial_lattice, final_lattice):

        # 좌표 하나씩 보간(interpolate)/ 보간 공식: interpol = ini + x * (fin - ini) 
        interpol_vec = [i_v + x * (f_v - i_v) for i_v, f_v in zip(vec_initial, vec_final)]

        # 중간 과정 lattice vector 저장
        intermediate_lattice.append(interpol_vec)
        

    # atom coords interpolation

    # 원자 좌표 보간 후 중간 과정 벡터 저장할 곳
    intermediate_coords = []

    # 원자 좌표를 한 줄씩 지정
    for row_initial, row_reordered in zip(initial_coords, reordered_coords):

        intermediate_coords_row =[]

        # 원자 좌표 한 개씩 지정
        for i_c, f_c in zip(row_initial, row_reordered):

            # pbc 고려해서 원자 좌표 차이 구하기
            interpol_difference = np.subtract (f_c, i_c)
            difference_round = np.round(interpol_difference)
            new_interpol_difference = interpol_difference - difference_round
        
            # 좌표 하나씩 보간(interpolate)/ 보간 공식: interpol = ini + x * (fin - ini)
            interpol_coords = i_c + x * (new_interpol_difference)

            # interpolated atom 1개 coords 저장
            intermediate_coords_row.append(interpol_coords)

        # 모든 interpolated atom의 coords 저장
        intermediate_coords.append(intermediate_coords_row)


    # 선형 보간된 구조 lattice vector와 atom 좌표로 저장
    interpolated_structures.append((intermediate_lattice, intermediate_coords))
    
print(interpolated_structures[0])
# Out:
# ([[5.60767179730625, 0.0, 0.0], [0.0, 22.538403511056252, 0.0], [0.0, 0.0, 5.57725411655625]], [[np.float64(0.190299555625), np.float64(0.0), np.float64(0.23440845856249998)], [np.float64(0.190299555625), np.float64(0.49999968218749996), np.float64(0.23440845856249998)], [np.float64(0.6902995753125), np.float64(0.0), np.float64(0.7655914998125)], [np.float64(0.6902995753125), np.float64(0.5000003178125), np.float64(0.7655914998125)], [np.float64(0.2836127753125), np.float64(0.341423579375), np.float64(0.2318887194375)], [np.float64(0.283610205625), np.float64(0.8414237649375), np.float64(0.231888018125)], [np.float64(0.783610185), np.float64(0.1585762560625), np.float64(0.768111921875)], [np.float64(0.7836127350000001), np.float64(0.658576420625), np.float64(0.7681112429375)], [np.float64(0.2836127753125), np.float64(0.1585764006875), np.float64(0.2318887194375)], [np.float64(0.283610205625), np.float64(0.6585762770625), np.float64(0.231888018125)], [np.float64(0.783610185), np.float64(0.341423742625), np.float64(0.768111921875)], [np.float64(0.7836127350000001), np.float64(0.8414236170625), np.float64(0.7681112429375)], [np.float64(0.239538638125), np.float64(0.08697002687500001), np.float64(0.7383663549375)], [np.float64(0.239538836875), np.float64(0.5869690108125), np.float64(0.7383625934375)], [np.float64(0.7395388574999999), np.float64(0.4130309515), np.float64(0.2616373241875)], [np.float64(0.739538698125), np.float64(0.9130299718125), np.float64(0.26163362575)], [np.float64(0.239538638125), np.float64(0.4130299744375), np.float64(0.7383663549375)], [np.float64(0.239538836875), np.float64(0.913030948875), np.float64(0.7383625934375)], [np.float64(0.7395388574999999), np.float64(0.08696904512499999), np.float64(0.2616373241875)], [np.float64(0.739538698125), np.float64(0.5869700308125), np.float64(0.26163362575)], [np.float64(0.29301118375), np.float64(0.25), np.float64(0.69237030825)], [np.float64(0.2930100090625), np.float64(0.749999979), np.float64(0.692375412375)], [np.float64(0.7930099490625), np.float64(0.25), np.float64(0.307624583625)], [np.float64(0.793011144375), np.float64(0.749999979), np.float64(0.30762969306250004)], [np.float64(0.030347403749999998), np.float64(0.3978677818125), np.float64(0.45683262131249996)], [np.float64(0.030346136250000003), np.float64(0.897867858875), np.float64(0.4568317474375)], [np.float64(0.030347403749999998), np.float64(0.10213223787499999), np.float64(0.45683262131249996)], [np.float64(0.030346136250000003), np.float64(0.6021320168125001), np.float64(0.4568317474375)], [np.float64(0.53034611125), np.float64(0.1021321085), np.float64(0.5431682525625)], [np.float64(0.53034739425), np.float64(0.602132135875), np.float64(0.543167338375)], [np.float64(0.53034611125), np.float64(0.397867900875), np.float64(0.5431682525625)], [np.float64(0.53034739425), np.float64(0.8978677791874999), np.float64(0.543167338375)], [np.float64(0.95206001875), np.float64(0.06963991018749999), np.float64(0.96438090625)], [np.float64(0.9520616921874999), np.float64(0.5696399295625), np.float64(0.96437834125)], [np.float64(0.95206001875), np.float64(0.4303600678125), np.float64(0.96438090625)], [np.float64(0.9520616921874999), np.float64(0.9303600704375), np.float64(0.96437834125)], [np.float64(0.45206171556249997), np.float64(0.4303600275), np.float64(0.0356217365625)], [np.float64(0.452060074125), np.float64(0.9303600704375), np.float64(0.0356190590625)], [np.float64(0.45206171556249997), np.float64(0.0696399645625), np.float64(0.0356217365625)], [np.float64(0.452060074125), np.float64(0.5696399295625), np.float64(0.0356190590625)], [np.float64(0.12854109018749998), np.float64(0.25), np.float64(0.38637714175)], [np.float64(0.1285423861875), np.float64(0.749999979), np.float64(0.3863798049375)], [np.float64(0.6285423948125), np.float64(0.25), np.float64(0.6136201976875)], [np.float64(0.6285411071875), np.float64(0.749999979), np.float64(0.6136228608750001)], [np.float64(0.264918341875), np.float64(0.0), np ...

# %%
# interpolation 파일들 저장 

# 파일 이름 설정하고 쓰기 모드로 열기
for i in range (n_steps):
    filename = f"POSCAR_interpolated_{i+1}.vasp"
    intermediate_lattice, intermediate_coords = interpolated_structures[i]
   
    with open(filename, 'w') as f:

        # 원자 이름 적기
        f.write(f"{initial_title}\n")

        # 스케일 벡터 적기
        f.write(f"{initial_scale}\n")

        # 라티스 벡터 한줄씩 적기
        for vec in intermediate_lattice:
                f.write("  " + "  ".join(f"{x:.10f}" for x in vec) + "\n")

        # 원자 종류 적기
        f.write("  " + "  ".join(initial_atom_types) + "\n")

        # 원자 종류별 갯수 적기
        f.write("  " + "  ".join(str(count) for count in initial_atom_counts) + "\n")

        # 좌표 형식 적기
        f.write(f"{initial_coord_type.capitalize()}\n")
        
        # 원자 좌표 한줄씩 적기
        for coord in intermediate_coords:
                f.write("  " + "  ".join(f"{x:.10f}" for x in coord) + "\n")

    print("저장됨:", filename)


# 저장된 'POSCAR_interpolated_1'파일 열어서 확인

filename = f"POSCAR_interpolated_{1}.vasp"
with open (filename, 'r') as f:
    content = f.read()

print(content)
# Out:
# 저장됨: POSCAR_interpolated_1.vasp
# 저장됨: POSCAR_interpolated_2.vasp
# 저장됨: POSCAR_interpolated_3.vasp
# 저장됨: POSCAR_interpolated_4.vasp
# 저장됨: POSCAR_interpolated_5.vasp
# 저장됨: POSCAR_interpolated_6.vasp
# 저장됨: POSCAR_interpolated_7.vasp
# 저장됨: POSCAR_interpolated_8.vasp
# 저장됨: POSCAR_interpolated_9.vasp
# 저장됨: POSCAR_interpolated_10.vasp
# 저장됨: POSCAR_interpolated_11.vasp
# 저장됨: POSCAR_interpolated_12.vasp
# 저장됨: POSCAR_interpolated_13.vasp
# 저장됨: POSCAR_interpolated_14.vasp
# 저장됨: POSCAR_interpolated_15.vasp
# Nd Ca Fe  O
# 1.0
#   5.6076717973  0.0000000000  0.0000000000
#   0.0000000000  22.5384035111  0.0000000000
#   0.0000000000  0.0000000000  5.5772541166
#   Nd  Ca  Fe  O
#   4  8  12  32
# Direct
#   0.1902995556  0.0000000000  0.2344084586
#   0.1902995556  0.4999996822  0.2344084586
#   0.6902995753  0.0000000000  0.7655914998
#   0.6902995753  0.5000003178  0.7655914998
#   0.2836127753  0.3414235794  0.2318887194
#   0.2836102056  0.8414237649  0.2318880181
#   0.7836101850  0.1585762561  0.7681119219
#   0.7836127350  0.6585764206  0.7681112429
#   0.2836127753  0.1585764007  0.2318887194
#   0.2836102056  0.6585762771  0.2318880181
#   0.7836101850  0.3414237426  0.7681119219
#   0.7836127350  0.8414236171  0.7681112429
#   0.2395386381  0.0869700269  0.7383663549
#   0.2395388369  0.5869690108  0.7383625934
#   0.7395388575  0.4130309515  0.2616373242
#   0.7395386981  0.9130299718  0.2616336257
#   0.2395386381  0.4130299744  0.7383663549
#   0.2395388369  0.9130309489  0.7383625934
#   0.7395388575  0.0869690451  0.2616373242
#   0.7395386981  0.5869700308  0.2616336257
#   0.2930111838  0.2500000000  0.6923703083
#   0.2930100091  0.7499999790  0.6923754124
#   0.7930099491  0.2500000000  0.3076245836
#   0.7930111444  0.7499999790  0.3076296931
#   0.0303474037  0.3978677818  0.4568326213
#   0.0303461363  0.8978678589  0.4568317474
#   0.0303474037  0.1021322379  0.4568326213
#   0.0303461363  0.6021320168  0.4568317474
#   0.5303461112  0.1021321085  0.5431682526
#   0.5303473942  0.6021321359  0.5431673384
#   0.5303461112  0.3978679009  0.5431682526
#   0.5303473942  0.8978677792  0.5431673384
#   0.9520600188  0.0696399102  0.9643809062
#   0.9520616922  0.5696399296  0.9643783412
#   0.9520600188  0.4303600678  0.9643809062
#   0.9520616922  0.9303600704  0.9643783412
#   0.4520617156  0.4303600275  0.0356217366
#   0.4520600741  0.9303600704  0.0356190591
#   0.4520617156  0.0696399646  0.0356217366
#   0.4520600741  0.5696399296  0.0356190591
#   0.1285410902  0.2500000000  0.3863771417
#   0.1285423862  0.7499999790  0.3863798049
#   0.6285423948  0.2500000000  0.6136201977
#   0.6285411072  0.7499999790  0.6136228609
#   0.2649183419  0.0000000000  0.6527692521
#   0.2649183419  0.5000000052  0.6527692521
#   0.7649183222  0.0000000000  0.3472307685
#   0.7649183222  0.5000000342  0.3472307685
#   0.2044951103  0.3216354415  0.8369673339
#   0.2044938756  0.8216358263  0.8369676755
#   0.7044938550  0.1783641527  0.1630322925
#   0.7044950906  0.6783645195  0.1630326761
#   0.2044951103  0.1783645585  0.8369673339
#   0.2044938756  0.6783641737  0.8369676755
#   0.7044938550  0.3216358473  0.1630322925
#   0.7044950906  0.8216354402  0.1630326761
