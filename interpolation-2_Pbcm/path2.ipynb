# %%
# 현재 작업 디렉터리 확인
# %pwd
# Out:
# 'c:\\Users\\osr11\\OneDrive\\바탕 화면\\interpolation-2_Pbcm'

# %%
# 디렉터리 내 파일 목록 확인
import os
file_list = os.listdir()
file_list
# Out:
# ['0_Pmma.vasp', '1_Pmc21.vasp', '2_Pbcm.vasp', 'path2.ipynb']

# %%
# .vasp로 끝나는 파일들만 poscar_files로 지정하고 확인
import glob
poscar_files = glob.glob("./*.vasp")
poscar_files
# Out:
# ['.\\0_Pmma.vasp', '.\\1_Pmc21.vasp', '.\\2_Pbcm.vasp']

# %%
# initial POSCAR file parsing

# poscar_files들 중 poscar_initial 파일을 지정(1_Pmc21.vasp를 poscar_initial 파일로 함.)
poscar_initial = poscar_files[1]
print(poscar_initial)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_initial_lines = open(poscar_initial, 'r')
initial_lines = read_initial_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
initial_title = initial_lines[0].strip()
print(initial_title)


# 스케일 팩터
initial_scale = float(initial_lines[1].strip())
print(initial_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
initial_lattice = []

for i in range(2,5):
    lattice_row_list = initial_lines[i].split()     #lattice_row_list = [a,b,c]의 리스트

    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))  

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성           
    initial_lattice.append(lattice_row)             

print(initial_lattice[0])
print(initial_lattice[1])
print(initial_lattice[2])


# 각 원자의 종류
initial_atom_types = initial_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나누고 각각 정수화 시켜 list로 만들기)
initial_atom_counts = []

initial_atom_counts_list = initial_lines[6].split()

for part in initial_atom_counts_list:
    initial_atom_counts.append(int(part))

print(initial_atom_counts)
print(type(initial_atom_counts[0]))


# 원자들 총 개수
initial_atoms_total = sum(initial_atom_counts)
print(initial_atoms_total)


# 원자 좌표의 형식
initial_coord_type = initial_lines[7].strip()
print(initial_coord_type)


# 각 atom들 좌표
initial_coords = []

for i in range(8,64):
    coords_row_list = initial_lines[i].split()      #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part))   
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 56개 리스트로 만들어서 전체 실수화 coord 리스트 완성           
    initial_coords.append(coords_row)
# Out:
# .\1_Pmc21.vasp
# Nd Ca Fe  O
# 1.0
# [5.6095247269, 0.0, 0.0]
# [0.0, 22.5286846161, 0.0]
# [0.0, 0.0, 5.5764307976]
# [4, 8, 12, 32]
# <class 'int'>
# 56
# Direct

# %%
# final POSCAR file parsing

# poscar_files들 중 poscar_final 파일을 지정 (2_Pbcm.vasp를 poscar_final 파일로 함.)
poscar_final = poscar_files[2]
print(poscar_final)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_final_lines = open(poscar_final, 'r')
final_lines = read_final_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
final_title = final_lines[0].strip()
print(final_title)


# 스케일 팩터
final_scale = float(final_lines[1].strip())
print(final_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
final_lattice = []

for i in range(2,5):
    lattice_row_list = final_lines[i].split()           #lattice_row_list = [a,b,c]의 리스트
    
    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성    
    final_lattice.append(lattice_row) 

print(final_lattice[0])
print(final_lattice[1])
print(final_lattice[2])


# 각 원자의 종류
final_atom_types = final_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나눠서 각각 정수화 시켜 list로 만들기)
final_atom_counts = []
final_atom_counts_list = final_lines[6].split()

for part in final_atom_counts_list:
    final_atom_counts.append(int(part))
    
print(final_atom_counts)
print(type(final_atom_counts[0]))


# 원자들 총 개수
final_atoms_total = sum(final_atom_counts)
print(final_atoms_total)


# 원자 좌표의 형식
final_coord_type = final_lines[7].strip()
print(final_coord_type)


# 각 atom들 좌표
final_coords = []

for i in range(8,64):
    coords_row_list = final_lines[i].split() #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part)) 
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 56개 리스트로 만들어서 전체 실수화 coord 리스트 완성 
    final_coords.append(coords_row) 

print(final_coords[0])
print(final_coords[1])
print(final_coords[2])
# Out:
# .\2_Pbcm.vasp
# Nd Ca Fe  O
# 1.0
# [5.6800179482, 0.0, 0.0]
# [0.0, 24.3015098572, 0.0]
# [0.0, 0.0, 5.7418723106]
# [4, 8, 12, 32]
# <class 'int'>
# 56
# Direct
# [0.24991945, 1.5908e-05, 0.244096538]
# [0.24991945, 0.499984067, 0.244096538]
# [0.750080529, 0.999984067, 0.755903441]

# %%
# labeling POSCAR file parsing

# poscar_files들 중 poscar_labeling 파일을 지정 (0_Pmma.vasp를 poscar_labeling 파일로 함.)
poscar_labeling = poscar_files[0]
print(poscar_labeling)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_labeling_lines = open(poscar_labeling, 'r')
labeling_lines = read_labeling_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
labeling_title = labeling_lines[0].strip()
print(labeling_title)


# 스케일 팩터
labeling_scale = float(labeling_lines[1].strip())
print(labeling_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
labeling_lattice = []

for i in range(2,5):
    lattice_row_list = labeling_lines[i].split()           #lattice_row_list = [a,b,c]의 리스트
    
    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성    
    labeling_lattice.append(lattice_row) 


# 각 원자의 종류
labeling_atom_types = labeling_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나눠서 각각 정수화 시켜 list로 만들기)
labeling_atom_counts = []
labeling_atom_counts_list = labeling_lines[6].split()

for part in labeling_atom_counts_list:
    labeling_atom_counts.append(int(part))
    
print(labeling_atom_counts)
print(type(labeling_atom_counts[0]))


# 원자들 총 개수
labeling_atoms_total = sum(labeling_atom_counts)
print(labeling_atoms_total)


# 원자 좌표의 형식
labeling_coord_type = labeling_lines[7].strip()
print(labeling_coord_type)


# 각 atom들 좌표
labeling_coords = []

for i in range(8,64):
    coords_row_list = labeling_lines[i].split() #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part)) 
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 56개 리스트로 만들어서 전체 실수화 coord 리스트 완성 
    labeling_coords.append(coords_row)
# Out:
# .\0_Pmma.vasp
# Nd Ca Fe  O
# 1.0
# [4, 8, 12, 32]
# <class 'int'>
# 56
# Direct

# %%
# initial_POSCAR <-> labeling_POSCAR Atom Labeling 


# 루트 연산을 위한 math, numpy 모듈
from math import sqrt
import numpy as np


# 재정렬된 코드/ 측정된 거리 넣을 빈 리스트
label_reordered_coords=[]
measured_distance = []

# base_atom_num: 기준이 되는 initial 원자 번호(순서)
for base_atom_num in range(initial_atoms_total):

    row_measured_distance = []

    # target_atom_num: initial 하나의 원자 기준으로 비교하는 final 원자 번호(순서)
    for target_atom_num in range(labeling_atoms_total):

        new_distance_difference = []

        # initial과 final 원자의 좌표 한개씩 꺼내기
        for i_c, l_c in zip(initial_coords[base_atom_num], labeling_coords[target_atom_num]):
            # 원자 좌표 차이
            distance_difference = np.subtract (i_c, l_c)
            # 좌표 차이 반올림
            difference_round = np.round(distance_difference)
            # pbc 고려된 좌표 차이
            new_distance_difference.append(distance_difference - difference_round)

        # 행렬 곱셈하기 위해 벡터를 행렬로 바꾸기
        new_distance_difference = np.array(new_distance_difference)
        lattice = np.array(initial_lattice)
        # 실제 거리를 반영한 원자 좌표 차이
        real_distance = new_distance_difference @ lattice

        # 각 좌표 차이 제곱의 합
        total = real_distance[0]**2 + real_distance[1]**2 + real_distance[2]**2
        # 최종 루트 씌우기(거리 공식)
        distance = sqrt(total)
        row_measured_distance.append(distance)

    # 계산한 실제 거리 저장 
    measured_distance.append(row_measured_distance)

# a: initial 원자의 순서
for a in range (initial_atoms_total):
    # atom_distance: initial 원자 하나에 대한 final 원자 56개와의 거리 리스트
    atom_distance = measured_distance[a]
    # list 중 가장 작은 값 확인
    min_distance = min(atom_distance)
    # 가장 작은 값 인덱스 확인
    min_distance_index = atom_distance.index(min_distance)
    # 인덱스 값 정수화
    min_index = int(min_distance_index)
    # 거리 차이가 가장 작은 값의 코드를 reordered_coords에 정렬
    label_reordered_coords.append(labeling_coords[min_index])


# labeling해서 재정렬 된 파일 저장

# 파일 이름 설정하고 쓰기 모드로 열기
filename = f"0_Pmma_reordered.vasp"
with open(filename, 'w') as f:
      
    # 원자 이름 적기
    f.write(f"{labeling_title}\n")
    # 스케일 벡터 적기
    f.write(f"{labeling_scale}\n")
    # 라티스 벡터 한줄씩 적기
    for vec in labeling_lattice:
            f.write("  " + "  ".join(f"{x:.10f}" for x in vec) + "\n")
    # 원자 종류 적기
    f.write("  " + "  ".join(final_atom_types) + "\n")
    # 원자 종류별 갯수 적기
    f.write("  " + "  ".join(str(count) for count in labeling_atom_counts) + "\n")
    # 좌표 형식 적기
    f.write(f"{labeling_coord_type.capitalize()}\n")
    # 원자 좌표 한줄씩 적기
    for coord in label_reordered_coords:
        f.write("  " + "  ".join(f"{x:.10f}" for x in coord) + "\n")

    print("저장됨:", filename)
# Out:
# 저장됨: 0_Pmma_reordered.vasp

# %%
# .vasp로 끝나는 파일들만 poscar_files로 지정하고 확인
import glob
poscar_files = glob.glob("./*.vasp")
poscar_files
# Out:
# ['.\\0_Pmma.vasp',
#  '.\\0_Pmma_reordered.vasp',
#  '.\\1_Pmc21.vasp',
#  '.\\2_Pbcm.vasp']

# %%
# new labeling POSCAR file parsing

# poscar_files들 중 poscar_labeling 파일을 지정 (0_Pmma_reordered.vasp를 poscar_new_labeling 파일로 함.)
poscar_new_labeling = poscar_files[1]
print(poscar_new_labeling)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_labeling_lines = open(poscar_new_labeling, 'r')
labeling_lines = read_labeling_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
labeling_title = labeling_lines[0].strip()
print(labeling_title)


# 스케일 팩터
labeling_scale = float(labeling_lines[1].strip())
print(labeling_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
labeling_lattice = []

for i in range(2,5):
    lattice_row_list = labeling_lines[i].split()           #lattice_row_list = [a,b,c]의 리스트
    
    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성    
    labeling_lattice.append(lattice_row) 


# 각 원자의 종류
labeling_atom_types = labeling_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나눠서 각각 정수화 시켜 list로 만들기)
labeling_atom_counts = []
labeling_atom_counts_list = labeling_lines[6].split()

for part in labeling_atom_counts_list:
    labeling_atom_counts.append(int(part))
    
print(labeling_atom_counts)
print(type(labeling_atom_counts[0]))


# 원자들 총 개수
labeling_atoms_total = sum(labeling_atom_counts)
print(labeling_atoms_total)


# 원자 좌표의 형식
labeling_coord_type = labeling_lines[7].strip()
print(labeling_coord_type)


# 각 atom들 좌표
labeling_coords = []

for i in range(8,64):
    coords_row_list = labeling_lines[i].split() #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part)) 
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 56개 리스트로 만들어서 전체 실수화 coord 리스트 완성 
    labeling_coords.append(coords_row)
# Out:
# .\0_Pmma_reordered.vasp
# Nd Ca Fe  O
# 1.0
# [4, 8, 12, 32]
# <class 'int'>
# 56
# Direct

# %%
# labeling_POSCAR <-> final_POSCAR Atom Labeling 


# 루트 연산을 위한 math, numpy 모듈
from math import sqrt
import numpy as np


# 재정렬된 코드/ 측정된 거리 넣을 빈 리스트
reordered_coords=[]
measured_distance = []

# base_atom_num: 기준이 되는 initial 원자 번호(순서)
for base_atom_num in range(labeling_atoms_total):

    row_measured_distance = []

    # target_atom_num: initial 하나의 원자 기준으로 비교하는 final 원자 번호(순서)
    for target_atom_num in range(final_atoms_total):

        new_distance_difference = []

        # initial과 final 원자의 좌표 한개씩 꺼내기
        for l_c, f_c in zip(labeling_coords[base_atom_num], final_coords[target_atom_num]):
            # 원자 좌표 차이
            distance_difference = np.subtract (l_c, f_c)
            # 좌표 차이 반올림
            difference_round = np.round(distance_difference)
            # pbc 고려된 좌표 차이
            new_distance_difference.append(distance_difference - difference_round)

        # 행렬 곱셈하기 위해 벡터를 행렬로 바꾸기
        new_distance_difference = np.array(new_distance_difference)
        lattice = np.array(labeling_lattice)
        # 실제 거리를 반영한 원자 좌표 차이
        real_distance = new_distance_difference @ lattice

        # 각 좌표 차이 제곱의 합
        total = real_distance[0]**2 + real_distance[1]**2 + real_distance[2]**2
        # 최종 루트 씌우기(거리 공식)
        distance = sqrt(total)
        row_measured_distance.append(distance)

    # 계산한 실제 거리 저장 
    measured_distance.append(row_measured_distance)

# a: initial 원자의 순서
for a in range (labeling_atoms_total):
    # atom_distance: initial 원자 하나에 대한 final 원자 56개와의 거리 리스트
    atom_distance = measured_distance[a]
    # list 중 가장 작은 값 확인
    min_distance = min(atom_distance)
    # 가장 작은 값 인덱스 확인
    min_distance_index = atom_distance.index(min_distance)
    # 인덱스 값 정수화
    min_index = int(min_distance_index)
    # 거리 차이가 가장 작은 값의 코드를 reordered_coords에 정렬
    reordered_coords.append(final_coords[min_index])




    # labeling해서 재정렬 된 파일 저장

# 파일 이름 설정하고 쓰기 모드로 열기
filename = f"2_Pbcm_reordered.vasp"
with open(filename, 'w') as f:
      
    # 원자 이름 적기
    f.write(f"{final_title}\n")
    # 스케일 벡터 적기
    f.write(f"{final_scale}\n")
    # 라티스 벡터 한줄씩 적기
    for vec in final_lattice:
            f.write("  " + "  ".join(f"{x:.10f}" for x in vec) + "\n")
    # 원자 종류 적기
    f.write("  " + "  ".join(final_atom_types) + "\n")
    # 원자 종류별 갯수 적기
    f.write("  " + "  ".join(str(count) for count in final_atom_counts) + "\n")
    # 좌표 형식 적기
    f.write(f"{final_coord_type.capitalize()}\n")
    # 원자 좌표 한줄씩 적기
    for coord in reordered_coords:
        f.write("  " + "  ".join(f"{x:.10f}" for x in coord) + "\n")

    print("저장됨:", filename)

# 저장된 파일 열어서 확인
filename = f"2_Pbcm_reordered.vasp"
with open (filename, 'r') as f:
    content = f.read()

print(content)
# Out:
# 저장됨: 2_Pbcm_reordered.vasp
# Nd Ca Fe  O
# 1.0
#   5.6800179482  0.0000000000  0.0000000000
#   0.0000000000  24.3015098572  0.0000000000
#   0.0000000000  0.0000000000  5.7418723106
#   Nd  Ca  Fe  O
#   4  8  12  32
# Direct
#   0.2499194500  0.0000159080  0.2440965380
#   0.2499194500  0.4999840670  0.2440965380
#   0.7500805290  0.9999840670  0.7559034410
#   0.7500805290  0.5000159330  0.7559034410
#   0.2630539640  0.3419605540  0.2488085860
#   0.2369287010  0.8419817460  0.2485713880
#   0.7630712780  0.1580182740  0.7514286120
#   0.7369461410  0.6580394460  0.7511914340
#   0.2630539640  0.1580394660  0.2488085860
#   0.2369287010  0.6580182940  0.2485713880
#   0.7630712780  0.3419817460  0.7514286120
#   0.7369461410  0.8419605540  0.7511914340
#   0.2542847420  0.0779221340  0.7419030340
#   0.2457719870  0.5779272250  0.7418179130
#   0.7542279920  0.4220728140  0.2581821080
#   0.7457153000  0.9220777980  0.2580969860
#   0.2542847420  0.4220778760  0.7419030340
#   0.2457719870  0.9220728530  0.7418179130
#   0.7542279920  0.0779271860  0.2581821080
#   0.7457153000  0.5779221630  0.2580969860
#   0.2745594290  0.2499999800  0.6985014170
#   0.2254575920  0.7499999610  0.6981372630
#   0.7745423660  0.2499999800  0.3018627370
#   0.7254405500  0.7499999610  0.3014985830
#   0.0161501670  0.4127300550  0.4867294810
#   0.9838497950  0.9127300150  0.5132705600
#   0.0161501670  0.0872699350  0.4867294810
#   0.9838497950  0.5872698280  0.5132705600
#   0.5161302670  0.0872878400  0.5133229620
#   0.4838696910  0.5872877230  0.4866770380
#   0.5161302670  0.4127121600  0.5133229620
#   0.4838696910  0.9127121200  0.4866770380
#   0.9945137880  0.0649414210  0.9914169890
#   0.0054861640  0.5649414210  0.0085830610
#   0.9945137880  0.4350585790  0.9914169890
#   0.0054861640  0.9350585000  0.0085830610
#   0.4945063160  0.4350484150  0.0086534590
#   0.5054936420  0.9350483750  0.9913465670
#   0.4945063160  0.0649516050  0.0086534590
#   0.5054936420  0.5649515850  0.9913465670
#   0.0812975300  0.2499999800  0.4286909960
#   0.9187024600  0.7499999610  0.5713089620
#   0.5813269230  0.2499999800  0.5717033870
#   0.4186730770  0.7499999610  0.4282966540
#   0.2499984050  -0.0000000000  0.6624752450
#   0.2499984050  0.5000005890  0.6624752450
#   0.7500015320  0.0000000000  0.3375247340
#   0.7500015320  0.4999994510  0.3375247340
#   0.2458918470  0.3238601950  0.8034350810
#   0.2541128120  0.8238527780  0.8031741520
#   0.7458871460  0.1761472620  0.1968258900
#   0.7541081110  0.6761398450  0.1965649600
#   0.2458918470  0.1761398250  0.8034350810
#   0.2541128120  0.6761473010  0.8031741520
#   0.7458871460  0.3238527380  0.1968258900
#   0.7541081110  0.8238602340  0.1965649600

# %%
# (interpolation)선형 보간하는 함수 정의


# 선형 보간된 구조 lattice vector와 atom 좌표 
interpolated_structures = []

# n개의 중간 과정 만들기
n_steps = 15                           # 중간 과정 개수
for step in range(1, n_steps + 1):     # 중간 과정 위치 (1부터 n_steps까지)
   

    # 보간 상수 x (중간 과정 위치 나타냄)
    # x는 곱해주는 비율(중간 과정을 3개로 만들면, 중간과정 1번 x=0.25/ 중간과정 2번 x=0.5/ 중간과정 3번 x=0.75)
    x = step / (n_steps + 1) 


    # lattice vector interpolation

    # 라티스 벡터 보간 후 중간 과정 벡터 저장할 빈 리스트
    intermediate_lattice = []

    # 3x3 라티스 벡터를 한 줄씩 지정
    for vec_initial, vec_final in zip(initial_lattice, final_lattice):

        # 좌표 하나씩 보간(interpolate)/ 보간 공식: interpol = ini + x * (fin - ini) 
        interpol_vec = [i_v + x * (f_v - i_v) for i_v, f_v in zip(vec_initial, vec_final)]

        # 중간 과정 lattice vector 저장
        intermediate_lattice.append(interpol_vec)
        

    # atom coords interpolation

    # 원자 좌표 보간 후 중간 과정 벡터 저장할 곳
    intermediate_coords = []

    # 원자 좌표를 한 줄씩 지정
    for row_initial, row_reordered in zip(initial_coords, reordered_coords):

        intermediate_coords_row =[]

        # 원자 좌표 한 개씩 지정
        for i_c, f_c in zip(row_initial, row_reordered):

            # pbc 고려해서 원자 좌표 차이 구하기
            interpol_difference = np.subtract (f_c, i_c)
            difference_round = np.round(interpol_difference)
            new_interpol_difference = interpol_difference - difference_round
        
            # 좌표 하나씩 보간(interpolate)/ 보간 공식: interpol = ini + x * (fin - ini)
            interpol_coords = i_c + x * (new_interpol_difference)

            # interpolated atom 1개 coords 저장
            intermediate_coords_row.append(interpol_coords)

        # 모든 interpolated atom의 coords 저장
        intermediate_coords.append(intermediate_coords_row)


    # 선형 보간된 구조 lattice vector와 atom 좌표로 저장
    interpolated_structures.append((intermediate_lattice, intermediate_coords))
    
print(interpolated_structures[0])
# Out:
# ([[5.61393055323125, 0.0, 0.0], [0.0, 22.639486193668752, 0.0], [0.0, 0.0, 5.5867708921625]], [[np.float64(0.19029452125000001), np.float64(9.9425e-07), np.float64(0.23514382643749998)], [np.float64(0.19029452125000001), np.float64(0.499998686375), np.float64(0.23514382643749998)], [np.float64(0.690304608375), np.float64(-9.958125000014695e-07), np.float64(0.7648561319375)], [np.float64(0.690304608375), np.float64(0.500001313625), np.float64(0.7648561319375)], [np.float64(0.2844286480625), np.float64(0.34164278275000004), np.float64(0.23085048381249998)], [np.float64(0.2827932494375), np.float64(0.8416443060000001), np.float64(0.23083483768750002)], [np.float64(0.784427139875), np.float64(0.1583557149375), np.float64(0.7691651023125)], [np.float64(0.7827968688125), np.float64(0.65835721725), np.float64(0.7691494771249999)], [np.float64(0.2844286480625), np.float64(0.15835719787500002), np.float64(0.23085048381249998)], [np.float64(0.2827932494375), np.float64(0.658355735875), np.float64(0.23083483768750002)], [np.float64(0.784427139875), np.float64(0.3416442863125), np.float64(0.7691651023125)], [np.float64(0.7827968688125), np.float64(0.8416428230625), np.float64(0.7691494771249999)], [np.float64(0.2398064345), np.float64(0.0864388911875), np.float64(0.73805949775)], [np.float64(0.2392745860625), np.float64(0.5864383759375), np.float64(0.7380506508125001)], [np.float64(0.739803107), np.float64(0.4135615861875), np.float64(0.2619492708125)], [np.float64(0.739270904375), np.float64(0.9135611045625), np.float64(0.261940482875)], [np.float64(0.2398064345), np.float64(0.4135611094375), np.float64(0.73805949775)], [np.float64(0.2392745860625), np.float64(0.913561588625), np.float64(0.7380506508125001)], [np.float64(0.739803107), np.float64(0.08643840912499999), np.float64(0.2619492708125)], [np.float64(0.739270904375), np.float64(0.5864388930000001), np.float64(0.261940482875)], [np.float64(0.2945461480625), np.float64(0.24999999875), np.float64(0.690535477625)], [np.float64(0.2914761085625), np.float64(0.7499999778750001), np.float64(0.6905166864375)], [np.float64(0.7945438469375), np.float64(0.24999999875), np.float64(0.3094833135625)], [np.float64(0.79147617875), np.float64(0.7499999778750001), np.float64(0.309464522375)], [np.float64(0.0313567891875), np.float64(0.3989796759375), np.float64(0.456003197875)], [np.float64(0.029336748437500004), np.float64(0.898979753125), np.float64(0.4576611734375)], [np.float64(0.0313567891875), np.float64(0.101020343125), np.float64(0.456003197875)], [np.float64(0.029336748437500004), np.float64(0.6010201180000001), np.float64(0.4576611734375)], [np.float64(0.53135425825), np.float64(0.1010213328125), np.float64(0.5440009216875)], [np.float64(0.5293392472499999), np.float64(0.6010213555), np.float64(0.54233466925)], [np.float64(0.53135425825), np.float64(0.3989786765625), np.float64(0.5440009216875)], [np.float64(0.5293392472499999), np.float64(0.898978555), np.float64(0.54233466925)], [np.float64(0.9517171305000001), np.float64(0.06952354131249999), np.float64(0.9638444680625)], [np.float64(0.9524045774375), np.float64(0.569523561), np.float64(0.9649147825625)], [np.float64(0.9517171305000001), np.float64(0.430476439), np.float64(0.9638444680625)], [np.float64(0.9524045774375), np.float64(0.9304764340625), np.float64(0.9649147825625)], [np.float64(0.4517183763125), np.float64(0.4304757634375), np.float64(0.03616257775)], [np.float64(0.45240341075), np.float64(0.9304758012500001), np.float64(0.0350782195)], [np.float64(0.4517183763125), np.float64(0.0695242321875), np.float64(0.03616257775)], [np.float64(0.45240341075), np.float64(0.56952419625), np.float64(0.0350782195)], [np.float64(0.13362233), np.float64(0.24999999875), np.float64(0.3819205769375)], [np.float64(0.1234611440625), np.float64(0.7499999778750001), np.float64(0.39083636450000003)], [np.float64(0.6336251833125), np.float64(0.24999999875), np.float64(0.6181019073125)], [np.float64(0.623458321375), np.float64(0.7499999778750001),  ...

# %%
# interpolation 파일들 저장 

# 파일 이름 설정하고 쓰기 모드로 열기
for i in range (n_steps):
    filename = f"POSCAR_interpolated_{i+1}.vasp"
    intermediate_lattice, intermediate_coords = interpolated_structures[i]
   
    with open(filename, 'w') as f:

        # 원자 이름 적기
        f.write(f"{initial_title}\n")

        # 스케일 벡터 적기
        f.write(f"{initial_scale}\n")

        # 라티스 벡터 한줄씩 적기
        for vec in intermediate_lattice:
                f.write("  " + "  ".join(f"{x:.10f}" for x in vec) + "\n")

        # 원자 종류 적기
        f.write("  " + "  ".join(initial_atom_types) + "\n")

        # 원자 종류별 갯수 적기
        f.write("  " + "  ".join(str(count) for count in initial_atom_counts) + "\n")

        # 좌표 형식 적기
        f.write(f"{initial_coord_type.capitalize()}\n")
        
        # 원자 좌표 한줄씩 적기
        for coord in intermediate_coords:
                f.write("  " + "  ".join(f"{x:.10f}" for x in coord) + "\n")

    print("저장됨:", filename)


# 저장된 'POSCAR_interpolated_1'파일 열어서 확인

filename = f"POSCAR_interpolated_{1}.vasp"
with open (filename, 'r') as f:
    content = f.read()

print(content)
# Out:
# 저장됨: POSCAR_interpolated_1.vasp
# 저장됨: POSCAR_interpolated_2.vasp
# 저장됨: POSCAR_interpolated_3.vasp
# 저장됨: POSCAR_interpolated_4.vasp
# 저장됨: POSCAR_interpolated_5.vasp
# 저장됨: POSCAR_interpolated_6.vasp
# 저장됨: POSCAR_interpolated_7.vasp
# 저장됨: POSCAR_interpolated_8.vasp
# 저장됨: POSCAR_interpolated_9.vasp
# 저장됨: POSCAR_interpolated_10.vasp
# 저장됨: POSCAR_interpolated_11.vasp
# 저장됨: POSCAR_interpolated_12.vasp
# 저장됨: POSCAR_interpolated_13.vasp
# 저장됨: POSCAR_interpolated_14.vasp
# 저장됨: POSCAR_interpolated_15.vasp
# Nd Ca Fe  O
# 1.0
#   5.6139305532  0.0000000000  0.0000000000
#   0.0000000000  22.6394861937  0.0000000000
#   0.0000000000  0.0000000000  5.5867708922
#   Nd  Ca  Fe  O
#   4  8  12  32
# Direct
#   0.1902945213  0.0000009943  0.2351438264
#   0.1902945213  0.4999986864  0.2351438264
#   0.6903046084  -0.0000009958  0.7648561319
#   0.6903046084  0.5000013136  0.7648561319
#   0.2844286481  0.3416427828  0.2308504838
#   0.2827932494  0.8416443060  0.2308348377
#   0.7844271399  0.1583557149  0.7691651023
#   0.7827968688  0.6583572172  0.7691494771
#   0.2844286481  0.1583571979  0.2308504838
#   0.2827932494  0.6583557359  0.2308348377
#   0.7844271399  0.3416442863  0.7691651023
#   0.7827968688  0.8416428231  0.7691494771
#   0.2398064345  0.0864388912  0.7380594978
#   0.2392745861  0.5864383759  0.7380506508
#   0.7398031070  0.4135615862  0.2619492708
#   0.7392709044  0.9135611046  0.2619404829
#   0.2398064345  0.4135611094  0.7380594978
#   0.2392745861  0.9135615886  0.7380506508
#   0.7398031070  0.0864384091  0.2619492708
#   0.7392709044  0.5864388930  0.2619404829
#   0.2945461481  0.2499999988  0.6905354776
#   0.2914761086  0.7499999779  0.6905166864
#   0.7945438469  0.2499999988  0.3094833136
#   0.7914761787  0.7499999779  0.3094645224
#   0.0313567892  0.3989796759  0.4560031979
#   0.0293367484  0.8989797531  0.4576611734
#   0.0313567892  0.1010203431  0.4560031979
#   0.0293367484  0.6010201180  0.4576611734
#   0.5313542583  0.1010213328  0.5440009217
#   0.5293392472  0.6010213555  0.5423346692
#   0.5313542583  0.3989786766  0.5440009217
#   0.5293392472  0.8989785550  0.5423346692
#   0.9517171305  0.0695235413  0.9638444681
#   0.9524045774  0.5695235610  0.9649147826
#   0.9517171305  0.4304764390  0.9638444681
#   0.9524045774  0.9304764341  0.9649147826
#   0.4517183763  0.4304757634  0.0361625778
#   0.4524034108  0.9304758013  0.0350782195
#   0.4517183763  0.0695242322  0.0361625778
#   0.4524034108  0.5695241962  0.0350782195
#   0.1336223300  0.2499999988  0.3819205769
#   0.1234611441  0.7499999779  0.3908363645
#   0.6336251833  0.2499999988  0.6181019073
#   0.6234583214  0.7499999779  0.6091411512
#   0.2649182422  0.0000000000  0.6535926584
#   0.2649182422  0.5000000762  0.6535926584
#   0.7649184179  0.0000000000  0.3464073609
#   0.7649184179  0.4999999657  0.3464073609
#   0.2042383508  0.3216128378  0.8330007213
#   0.2047509264  0.8216126921  0.8329845736
#   0.7042368016  0.1783872908  0.1670153991
#   0.7047518476  0.6783871244  0.1669992906
#   0.2042383508  0.1783871634  0.8330007213
#   0.2047509264  0.6783873129  0.8329845736
#   0.7042368016  0.3216127093  0.1670153991
#   0.7047518476  0.8216128403  0.1669992906
