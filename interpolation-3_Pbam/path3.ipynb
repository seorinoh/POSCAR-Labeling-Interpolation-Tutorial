# %%
# 현재 작업 디렉터리 확인
# %pwd
# Out:
# 'c:\\Users\\osr11\\OneDrive\\바탕 화면\\interpolation-3_Pbam'

# %%
# 디렉터리 내 파일 목록 확인
import os
file_list = os.listdir()
file_list
# Out:
# ['0_Pmma_supercell.vasp',
#  '1_Pmc21_supercell.vasp',
#  '3_Pbam.vasp',
#  'path3.ipynb']

# %%
# .vasp로 끝나는 파일들만 poscar_files로 지정하고 확인
import glob
poscar_files = glob.glob("./*.vasp")
poscar_files
# Out:
# ['.\\0_Pmma_supercell.vasp', '.\\1_Pmc21_supercell.vasp', '.\\3_Pbam.vasp']

# %%
# initial POSCAR file parsing

# poscar_files들 중 poscar_initial 파일을 지정(1_Pmc21_supercell.vasp를 poscar_initial 파일로 함.)
poscar_initial = poscar_files[1]
print(poscar_initial)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_initial_lines = open(poscar_initial, 'r')
initial_lines = read_initial_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
initial_title = initial_lines[0].strip()
print(initial_title)


# 스케일 팩터
initial_scale = float(initial_lines[1].strip())
print(initial_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
initial_lattice = []

for i in range(2,5):
    lattice_row_list = initial_lines[i].split()     #lattice_row_list = [a,b,c]의 리스트

    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))  

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성           
    initial_lattice.append(lattice_row)             

print(initial_lattice[0])
print(initial_lattice[1])
print(initial_lattice[2])


# 각 원자의 종류
initial_atom_types = initial_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나누고 각각 정수화 시켜 list로 만들기)
initial_atom_counts = []

initial_atom_counts_list = initial_lines[6].split()

for part in initial_atom_counts_list:
    initial_atom_counts.append(int(part))

print(initial_atom_counts)
print(type(initial_atom_counts[0]))


# 원자들 총 개수
initial_atoms_total = sum(initial_atom_counts)
print(initial_atoms_total)


# 원자 좌표의 형식
initial_coord_type = initial_lines[7].strip()
print(initial_coord_type)


# 각 atom들 좌표
initial_coords = []

for i in range(8,120):
    coords_row_list = initial_lines[i].split()      #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part))   
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 112개 리스트로 만들어서 전체 실수화 coord 리스트 완성           
    initial_coords.append(coords_row)         

print(initial_coords[0])
print(initial_coords[1])
print(initial_coords[2])
# Out:
# .\1_Pmc21_supercell.vasp
# Nd Ca Fe  O
# 1.0
# [5.6095247269, 0.0, 0.0]
# [0.0, 22.5286846161, 0.0]
# [0.0, 0.0, 11.1528615952]
# [8, 16, 24, 64]
# <class 'int'>
# 112
# Direct
# [0.186319526, 0.0, 0.117273489]
# [0.186319526, 0.0, 0.61727349]
# [0.186319526, 0.499999661, 0.117273489]

# %%
# final POSCAR file parsing

# poscar_files들 중 poscar_final 파일을 지정 (3_Pbam.vasp를 poscar_final 파일로 함.)
poscar_final = poscar_files[2]
print(poscar_final)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_final_lines = open(poscar_final, 'r')
final_lines = read_final_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
final_title = final_lines[0].strip()
print(final_title)


# 스케일 팩터
final_scale = float(final_lines[1].strip())
print(final_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
final_lattice = []

for i in range(2,5):
    lattice_row_list = final_lines[i].split()           #lattice_row_list = [a,b,c]의 리스트
    
    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성    
    final_lattice.append(lattice_row) 

print(final_lattice[0])
print(final_lattice[1])
print(final_lattice[2])


# 각 원자의 종류
final_atom_types = final_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나눠서 각각 정수화 시켜 list로 만들기)
final_atom_counts = []
final_atom_counts_list = final_lines[6].split()

for part in final_atom_counts_list:
    final_atom_counts.append(int(part))
    
print(final_atom_counts)
print(type(final_atom_counts[0]))


# 원자들 총 개수
final_atoms_total = sum(final_atom_counts)
print(final_atoms_total)


# 원자 좌표의 형식
final_coord_type = final_lines[7].strip()
print(final_coord_type)


# 각 atom들 좌표
final_coords = []

for i in range(8,120):
    coords_row_list = final_lines[i].split() #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part)) 
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 112개 리스트로 만들어서 전체 실수화 coord 리스트 완성 
    final_coords.append(coords_row) 

print(final_coords[0])
print(final_coords[1])
print(final_coords[2])
# Out:
# .\3_Pbam.vasp
# findsym-output Pbam
# 1.0
# [5.5355443954, 0.0, 0.0]
# [0.0, 22.5120067596, 0.0]
# [0.0, 0.0, 11.2799797058]
# [8, 16, 24, 64]
# <class 'int'>
# 112
# Direct
# [0.256237726, -0.0, 0.116699214]
# [0.243762296, 0.0, 0.616699214]
# [0.256237726, 0.49999928, 0.116699214]

# %%
# labeling POSCAR file parsing

# poscar_files들 중 poscar_labeling 파일을 지정 (0_Pmma.vasp를 poscar_labeling 파일로 함.)
poscar_labeling = poscar_files[0]
print(poscar_labeling)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_labeling_lines = open(poscar_labeling, 'r')
labeling_lines = read_labeling_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
labeling_title = labeling_lines[0].strip()
print(labeling_title)


# 스케일 팩터
labeling_scale = float(labeling_lines[1].strip())
print(labeling_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
labeling_lattice = []

for i in range(2,5):
    lattice_row_list = labeling_lines[i].split()           #lattice_row_list = [a,b,c]의 리스트
    
    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성    
    labeling_lattice.append(lattice_row) 


# 각 원자의 종류
labeling_atom_types = labeling_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나눠서 각각 정수화 시켜 list로 만들기)
labeling_atom_counts = []
labeling_atom_counts_list = labeling_lines[6].split()

for part in labeling_atom_counts_list:
    labeling_atom_counts.append(int(part))
    
print(labeling_atom_counts)
print(type(labeling_atom_counts[0]))


# 원자들 총 개수
labeling_atoms_total = sum(labeling_atom_counts)
print(labeling_atoms_total)


# 원자 좌표의 형식
labeling_coord_type = labeling_lines[7].strip()
print(labeling_coord_type)


# 각 atom들 좌표
labeling_coords = []

for i in range(8,120):
    coords_row_list = labeling_lines[i].split() #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part)) 
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 112개 리스트로 만들어서 전체 실수화 coord 리스트 완성 
    labeling_coords.append(coords_row)
# Out:
# .\0_Pmma_supercell.vasp
# Nd Ca Fe  O
# 1.0
# [8, 16, 24, 64]
# <class 'int'>
# 112
# Direct

# %%
# initial_POSCAR <-> labeling_POSCAR Atom Labeling 


# 루트 연산을 위한 math, numpy 모듈
from math import sqrt
import numpy as np


# 재정렬된 코드/ 측정된 거리 넣을 빈 리스트
label_reordered_coords=[]
measured_distance = []

# base_atom_num: 기준이 되는 initial 원자 번호(순서)
for base_atom_num in range(initial_atoms_total):

    row_measured_distance = []

    # target_atom_num: initial 하나의 원자 기준으로 비교하는 final 원자 번호(순서)
    for target_atom_num in range(labeling_atoms_total):

        new_distance_difference = []

        # initial과 final 원자의 좌표 한개씩 꺼내기
        for i_c, l_c in zip(initial_coords[base_atom_num], labeling_coords[target_atom_num]):
            # 원자 좌표 차이
            distance_difference = np.subtract (i_c, l_c)
            # 좌표 차이 반올림
            difference_round = np.round(distance_difference)
            # pbc 고려된 좌표 차이
            new_distance_difference.append(distance_difference - difference_round)

        # 행렬 곱셈하기 위해 벡터를 행렬로 바꾸기
        new_distance_difference = np.array(new_distance_difference)
        lattice = np.array(initial_lattice)
        # 실제 거리를 반영한 원자 좌표 차이
        real_distance = new_distance_difference @ lattice

        # 각 좌표 차이 제곱의 합
        total = real_distance[0]**2 + real_distance[1]**2 + real_distance[2]**2
        # 최종 루트 씌우기(거리 공식)
        distance = sqrt(total)
        row_measured_distance.append(distance)

    # 계산한 실제 거리 저장 
    measured_distance.append(row_measured_distance)

# a: initial 원자의 순서
for a in range (initial_atoms_total):
    # atom_distance: initial 원자 하나에 대한 final 원자 112개와의 거리 리스트
    atom_distance = measured_distance[a]
    # list 중 가장 작은 값 확인
    min_distance = min(atom_distance)
    # 가장 작은 값 인덱스 확인
    min_distance_index = atom_distance.index(min_distance)
    # 인덱스 값 정수화
    min_index = int(min_distance_index)
    # 거리 차이가 가장 작은 값의 코드를 reordered_coords에 정렬
    label_reordered_coords.append(labeling_coords[min_index])


# labeling해서 재정렬 된 파일 저장

# 파일 이름 설정하고 쓰기 모드로 열기
filename = f"0_Pmma_supercell_reordered.vasp"
with open(filename, 'w') as f:
      
    # 원자 이름 적기
    f.write(f"{labeling_title}\n")
    # 스케일 벡터 적기
    f.write(f"{labeling_scale}\n")
    # 라티스 벡터 한줄씩 적기
    for vec in labeling_lattice:
            f.write("  " + "  ".join(f"{x:.10f}" for x in vec) + "\n")
    # 원자 종류 적기
    f.write("  " + "  ".join(final_atom_types) + "\n")
    # 원자 종류별 갯수 적기
    f.write("  " + "  ".join(str(count) for count in labeling_atom_counts) + "\n")
    # 좌표 형식 적기
    f.write(f"{labeling_coord_type.capitalize()}\n")
    # 원자 좌표 한줄씩 적기
    for coord in label_reordered_coords:
        f.write("  " + "  ".join(f"{x:.10f}" for x in coord) + "\n")

    print("저장됨:", filename)
# Out:
# 저장됨: 0_Pmma_supercell_reordered.vasp

# %%
# .vasp로 끝나는 파일들만 poscar_files로 지정하고 확인
import glob
poscar_files = glob.glob("./*.vasp")
poscar_files
# Out:
# ['.\\0_Pmma_supercell.vasp',
#  '.\\0_Pmma_supercell_reordered.vasp',
#  '.\\1_Pmc21_supercell.vasp',
#  '.\\3_Pbam.vasp']

# %%
# new labeling POSCAR file parsing

# poscar_files들 중 poscar_labeling 파일을 지정 (0_Pmma_supercell_reordered.vasp를 poscar_new_labeling 파일로 함.)
poscar_new_labeling = poscar_files[1]
print(poscar_new_labeling)

# poscar 파일 내용을 줄 마다 정의하기 위해 읽기 모드로 열기
read_labeling_lines = open(poscar_new_labeling, 'r')
labeling_lines = read_labeling_lines.readlines()


# poscar 파일 줄별로 파싱하기

# 구조 이름
labeling_title = labeling_lines[0].strip()
print(labeling_title)


# 스케일 팩터
labeling_scale = float(labeling_lines[1].strip())
print(labeling_scale)


# float는 list 못받음 -> 문자열 하나만 받을 수 있음(즉, lattice 벡터 한 줄씩 실수화(float) 시킬 수 없음)
# 3x3 라티스 벡터(POSCAR 파일 2,3,4번째 줄)
# 한 줄씩, 한 줄당 3개의 좌표를 한 개씩 쪼개서 문자를 실수화(float) -> 한 줄 list만들고 -> 각 줄 합쳐서 list로 만들기
labeling_lattice = []

for i in range(2,5):
    lattice_row_list = labeling_lines[i].split()           #lattice_row_list = [a,b,c]의 리스트
    
    lattice_row = []

    for part in lattice_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        lattice_row.append(float(part))

    #[a,b,c]/ [d,e,f]/ [g,h,i] 3개 리스트로 만들어서 전체 실수화 lattice 리스트 완성    
    labeling_lattice.append(lattice_row) 


# 각 원자의 종류
labeling_atom_types = labeling_lines[5].split()


# 각 원자 종류별 개수(공백 기준으로 원자 수 나눠서 각각 정수화 시켜 list로 만들기)
labeling_atom_counts = []
labeling_atom_counts_list = labeling_lines[6].split()

for part in labeling_atom_counts_list:
    labeling_atom_counts.append(int(part))
    
print(labeling_atom_counts)
print(type(labeling_atom_counts[0]))


# 원자들 총 개수
labeling_atoms_total = sum(labeling_atom_counts)
print(labeling_atoms_total)


# 원자 좌표의 형식
labeling_coord_type = labeling_lines[7].strip()
print(labeling_coord_type)


# 각 atom들 좌표
labeling_coords = []

for i in range(8,120):
    coords_row_list = labeling_lines[i].split() #coords_row_list = [a,b,c]의 리스트

    coords_row = []
    for part in coords_row_list:
        # a,b,c 좌표 하나씩 실수화 해서 [a,b,c] 리스트로 만들기
        coords_row.append(float(part)) 
    #[a,b,c]/ [d,e,f]/ [g,h,i] ...총 112개 리스트로 만들어서 전체 실수화 coord 리스트 완성 
    labeling_coords.append(coords_row)
# Out:
# .\0_Pmma_supercell_reordered.vasp
# Nd Ca Fe  O
# 1.0
# [8, 16, 24, 64]
# <class 'int'>
# 112
# Direct

# %%
# labeling_POSCAR <-> final_POSCAR Atom Labeling 


# 루트 연산을 위한 math, numpy 모듈
from math import sqrt
import numpy as np


# 재정렬된 코드/ 측정된 거리 넣을 빈 리스트
reordered_coords=[]
measured_distance = []

# base_atom_num: 기준이 되는 initial 원자 번호(순서)
for base_atom_num in range(labeling_atoms_total):

    row_measured_distance = []

    # target_atom_num: initial 하나의 원자 기준으로 비교하는 final 원자 번호(순서)
    for target_atom_num in range(final_atoms_total):

        new_distance_difference = []

        # initial과 final 원자의 좌표 한개씩 꺼내기
        for l_c, f_c in zip(labeling_coords[base_atom_num], final_coords[target_atom_num]):
            # 원자 좌표 차이
            distance_difference = np.subtract (l_c, f_c)
            # 좌표 차이 반올림
            difference_round = np.round(distance_difference)
            # pbc 고려된 좌표 차이
            new_distance_difference.append(distance_difference - difference_round)

        # 행렬 곱셈하기 위해 벡터를 행렬로 바꾸기
        new_distance_difference = np.array(new_distance_difference)
        lattice = np.array(labeling_lattice)
        # 실제 거리를 반영한 원자 좌표 차이
        real_distance = new_distance_difference @ lattice

        # 각 좌표 차이 제곱의 합
        total = real_distance[0]**2 + real_distance[1]**2 + real_distance[2]**2
        # 최종 루트 씌우기(거리 공식)
        distance = sqrt(total)
        row_measured_distance.append(distance)

    # 계산한 실제 거리 저장 
    measured_distance.append(row_measured_distance)

# a: initial 원자의 순서
for a in range (labeling_atoms_total):
    # atom_distance: initial 원자 하나에 대한 final 원자 112개와의 거리 리스트
    atom_distance = measured_distance[a]
    # list 중 가장 작은 값 확인
    min_distance = min(atom_distance)
    # 가장 작은 값 인덱스 확인
    min_distance_index = atom_distance.index(min_distance)
    # 인덱스 값 정수화
    min_index = int(min_distance_index)
    # 거리 차이가 가장 작은 값의 코드를 reordered_coords에 정렬
    reordered_coords.append(final_coords[min_index])


print(reordered_coords)
print(len(reordered_coords))
print(reordered_coords[0])
print(reordered_coords[1])
print(reordered_coords[41])
print(reordered_coords[43])
# Out:
# [[0.256237726, -0.0, 0.116699214], [0.243762296, 0.0, 0.616699214], [0.256237726, 0.49999928, 0.116699214], [0.243762296, 0.49999928, 0.616699214], [0.756237683, -0.0, 0.383300786], [0.743762317, 0.0, 0.883300744], [0.756237683, 0.50000072, 0.383300786], [0.743762317, 0.50000072, 0.883300744], [0.213048991, 0.342567617, 0.115299781], [0.286951009, 0.342567617, 0.61529977], [0.213049638, 0.842568379, 0.115304167], [0.286950341, 0.842568379, 0.615304167], [0.713049659, 0.157431621, 0.384695833], [0.786950384, 0.157431621, 0.884695833], [0.713049013, 0.657432383, 0.38470023], [0.786950987, 0.657432383, 0.88470023], [0.213048991, 0.157432373, 0.115299781], [0.286951009, 0.157432373, 0.61529977], [0.213049638, 0.657431621, 0.115304167], [0.286950341, 0.657431621, 0.615304167], [0.713049659, 0.3425684, 0.384695833], [0.786950384, 0.3425684, 0.884695833], [0.713049013, 0.842567617, 0.38470023], [0.786950987, 0.842567617, 0.88470023], [0.238526927, 0.087160551, 0.368633452], [0.261473051, 0.087160551, 0.868633409], [0.238528284, 0.587160647, 0.368636664], [0.261471716, 0.587160647, 0.868636707], [0.738528306, 0.412839353, 0.131363336], [0.761471694, 0.412839353, 0.631363336], [0.738526927, 0.912839396, 0.13136657], [0.761473073, 0.912839396, 0.631366548], [0.238526927, 0.412839438, 0.368633452], [0.261473051, 0.412839438, 0.868633409], [0.238528284, 0.912839311, 0.368636664], [0.261471716, 0.912839311, 0.868636707], [0.738528306, 0.087160641, 0.131363336], [0.761471694, 0.087160641, 0.631363336], [0.738526927, 0.587160604, 0.13136657], [0.761473073, 0.587160604, 0.631366548], [0.188407183, 0.25, 0.344374952], [0.311592817, 0.25, 0.844374952], [0.188405891, 0.749999979, 0.344377192], [0.311594109, 0.749999979, 0.844377234], [0.688405891, 0.25, 0.155622808], [0.811594109, 0.25, 0.655622766], [0.688407183, 0.749999979, 0.155625059], [0.811592817, 0.749999979, 0.655625091], [0.971506549, 0.396200809, 0.258803664], [0.02849599, 0.39620119, 0.741191855], [0.971503964, 0.89620119, 0.258808187], [0.028493446, 0.896200851, 0.741196336], [0.971506549, 0.10379917, 0.258803664], [0.02849599, 0.103798821, 0.741191855], [0.971503964, 0.603798768, 0.258808187], [0.028493446, 0.603799064, 0.741196336], [0.471504008, 0.103798821, 0.241191834], [0.528493451, 0.10379917, 0.758803664], [0.471506549, 0.603799064, 0.241196315], [0.528495949, 0.603798768, 0.75880823], [0.471504008, 0.39620119, 0.241191834], [0.528493451, 0.396200809, 0.758803664], [0.471506549, 0.896200851, 0.241196315], [0.528495949, 0.89620119, 0.75880823], [-0.0, 0.068821998, 0.499998098], [0.0, 0.069661203, 0.999998055], [-0.0, 0.568822035, 0.500001902], [0.0, 0.569661203, 1.895e-06], [-0.0, 0.431178007, 0.499998098], [0.0, 0.430338797, 0.999998055], [0.0, 0.931177965, 0.500001902], [-0.0, 0.930338755, 1.895e-06], [0.499999742, 0.431178007, 0.999998055], [0.500000904, 0.430338797, 0.499998098], [0.500000258, 0.931177965, 1.905e-06], [0.499999139, 0.930338755, 0.500001902], [0.499999742, 0.068821998, 0.999998055], [0.500000904, 0.069661203, 0.499998098], [0.500000258, 0.568822035, 1.905e-06], [0.499999139, 0.569661203, 0.500001902], [0.841573406, 0.25, 0.311525547], [0.158425151, 0.25, 0.688471367], [0.841574871, 0.749999979, 0.311528675], [0.158426615, 0.749999979, 0.688474495], [0.341574849, 0.25, 0.188471346], [0.658426637, 0.25, 0.811525547], [0.341573385, 0.749999979, 0.188474474], [0.658425173, 0.749999979, 0.811528675], [0.232696562, 0.0, 0.324869508], [0.267303438, -0.0, 0.824869487], [0.232696562, 0.500000254, 0.324869508], [0.267303438, 0.500000254, 0.824869487], [0.732696562, 0.0, 0.175130513], [0.767303438, 0.0, 0.675130471], [0.732696562, 0.499999788, 0.175130513], [0.767303438, 0.499999788, 0.675130471], [0.271776566, 0.321748318, 0.417491509], [0.228223434, 0.321748318, 0.917491551], [0.271772647, 0.821748275, 0.417494933], [0.228227353, 0.821748275, 0.917494933], [0.771772604, 0.178251682, 0.082505062], [0.72822731, 0.178251682, 0.582505067], [0.771776566, 0.678251682, 0. ...
# 112
# [0.256237726, -0.0, 0.116699214]
# [0.243762296, 0.0, 0.616699214]
# [0.311592817, 0.25, 0.844374952]
# [0.311594109, 0.749999979, 0.844377234]

# %%
# labeling해서 재정렬 된 파일 저장

# 파일 이름 설정하고 쓰기 모드로 열기
filename = f"3_Pbam_reordered.vasp"
with open(filename, 'w') as f:
      
    # 원자 이름 적기
    f.write(f"{final_title}\n")
    # 스케일 벡터 적기
    f.write(f"{final_scale}\n")
    # 라티스 벡터 한줄씩 적기
    for vec in final_lattice:
            f.write("  " + "  ".join(f"{x:.10f}" for x in vec) + "\n")
    # 원자 종류 적기
    f.write("  " + "  ".join(final_atom_types) + "\n")
    # 원자 종류별 갯수 적기
    f.write("  " + "  ".join(str(count) for count in final_atom_counts) + "\n")
    # 좌표 형식 적기
    f.write(f"{final_coord_type.capitalize()}\n")
    # 원자 좌표 한줄씩 적기
    for coord in reordered_coords:
        f.write("  " + "  ".join(f"{x:.10f}" for x in coord) + "\n")

    print("저장됨:", filename)

# 저장된 파일 열어서 확인
filename = f"3_Pbam_reordered.vasp"
with open (filename, 'r') as f:
    content = f.read()

print(content)
# Out:
# 저장됨: 3_Pbam_reordered.vasp
# findsym-output Pbam
# 1.0
#   5.5355443954  0.0000000000  0.0000000000
#   0.0000000000  22.5120067596  0.0000000000
#   0.0000000000  0.0000000000  11.2799797058
#   Nd  Ca  Fe  O
#   8  16  24  64
# Direct
#   0.2562377260  -0.0000000000  0.1166992140
#   0.2437622960  0.0000000000  0.6166992140
#   0.2562377260  0.4999992800  0.1166992140
#   0.2437622960  0.4999992800  0.6166992140
#   0.7562376830  -0.0000000000  0.3833007860
#   0.7437623170  0.0000000000  0.8833007440
#   0.7562376830  0.5000007200  0.3833007860
#   0.7437623170  0.5000007200  0.8833007440
#   0.2130489910  0.3425676170  0.1152997810
#   0.2869510090  0.3425676170  0.6152997700
#   0.2130496380  0.8425683790  0.1153041670
#   0.2869503410  0.8425683790  0.6153041670
#   0.7130496590  0.1574316210  0.3846958330
#   0.7869503840  0.1574316210  0.8846958330
#   0.7130490130  0.6574323830  0.3847002300
#   0.7869509870  0.6574323830  0.8847002300
#   0.2130489910  0.1574323730  0.1152997810
#   0.2869510090  0.1574323730  0.6152997700
#   0.2130496380  0.6574316210  0.1153041670
#   0.2869503410  0.6574316210  0.6153041670
#   0.7130496590  0.3425684000  0.3846958330
#   0.7869503840  0.3425684000  0.8846958330
#   0.7130490130  0.8425676170  0.3847002300
#   0.7869509870  0.8425676170  0.8847002300
#   0.2385269270  0.0871605510  0.3686334520
#   0.2614730510  0.0871605510  0.8686334090
#   0.2385282840  0.5871606470  0.3686366640
#   0.2614717160  0.5871606470  0.8686367070
#   0.7385283060  0.4128393530  0.1313633360
#   0.7614716940  0.4128393530  0.6313633360
#   0.7385269270  0.9128393960  0.1313665700
#   0.7614730730  0.9128393960  0.6313665480
#   0.2385269270  0.4128394380  0.3686334520
#   0.2614730510  0.4128394380  0.8686334090
#   0.2385282840  0.9128393110  0.3686366640
#   0.2614717160  0.9128393110  0.8686367070
#   0.7385283060  0.0871606410  0.1313633360
#   0.7614716940  0.0871606410  0.6313633360
#   0.7385269270  0.5871606040  0.1313665700
#   0.7614730730  0.5871606040  0.6313665480
#   0.1884071830  0.2500000000  0.3443749520
#   0.3115928170  0.2500000000  0.8443749520
#   0.1884058910  0.7499999790  0.3443771920
#   0.3115941090  0.7499999790  0.8443772340
#   0.6884058910  0.2500000000  0.1556228080
#   0.8115941090  0.2500000000  0.6556227660
#   0.6884071830  0.7499999790  0.1556250590
#   0.8115928170  0.7499999790  0.6556250910
#   0.9715065490  0.3962008090  0.2588036640
#   0.0284959900  0.3962011900  0.7411918550
#   0.9715039640  0.8962011900  0.2588081870
#   0.0284934460  0.8962008510  0.7411963360
#   0.9715065490  0.1037991700  0.2588036640
#   0.0284959900  0.1037988210  0.7411918550
#   0.9715039640  0.6037987680  0.2588081870
#   0.0284934460  0.6037990640  0.7411963360
#   0.4715040080  0.1037988210  0.2411918340
#   0.5284934510  0.1037991700  0.7588036640
#   0.4715065490  0.6037990640  0.2411963150
#   0.5284959490  0.6037987680  0.7588082300
#   0.4715040080  0.3962011900  0.2411918340
#   0.5284934510  0.3962008090  0.7588036640
#   0.4715065490  0.8962008510  0.2411963150
#   0.5284959490  0.8962011900  0.7588082300
#   -0.0000000000  0.0688219980  0.4999980980
#   0.0000000000  0.0696612030  0.9999980550
#   -0.0000000000  0.5688220350  0.5000019020
#   0.0000000000  0.5696612030  0.0000018950
#   -0.0000000000  0.4311780070  0.4999980980
#   0.0000000000  0.4303387970  0.9999980550
#   0.0000000000  0.9311779650  0.5000019020
#   -0.0000000000  0.9303387550  0.0000018950
#   0.4999997420  0.4311780070  0.9999980550
#   0.5000009040  0.4303387970  0.4999980980
#   0.5000002580  0.9311779650  0.0000019050
#   0.4999991390  0.9303387550  0.5000019020
#   0.4999997420  0.0688219980  0.9999980550
#   0.5000009040  0.0696612030  0.4999980980
#   0.5000002580  0.5688220350  0.0000019050
#   0.4999991390  0.5696612030  0.5000019020
#   0.8415734060  0.2500000000  0.3115255470
#   0.1584251510  0.2500000000  0.6884713670
#   0.8415748710  0.7499999790  0.3115286750
#   0.1584266150  0.7499999790  0.6884744950
#   0.3415748490  0.2500000000  0.1884713460
#   0.6584266370  0.2500000000  0.8115255470
#   0.3415733850  0.7499999790  0.1884744740
#   0.6584251730  0.7499999790  0.8115286750
#   0.2326965620  0.0000000000  0.3248695080
#   0.2673034380  -0.0000000000  0.8248694870
#   0.2326965620  0.5000002540  0.3248695080
#   0.2673034380  0.5000002540  0.8248694870
#   0.7326965620  0.0000000000  0.1751305130
#   0.7673034380  0.0000000000  0.6751304710
#   0.7326965620  0.4999997880  0.1751305130
#   0.7673034380  0.4999997880  0.6751304710
#   0.2717765660  0.3217483180  0.4174915090
#   0.2282234340  0.3217483180  0.9174915510
#   0.2717726470  0.8217482750  0.4174949330
#   0.2282273530  0.8217482750  0.9174949330
#   0.7717726040  0.1782516820  0.0825050620
#   0.7282273100  0.1782516820  0.5825050670
#   0.7717765660  0.6782516820  0.0825084800
#   0.7282234340  0.6782516820  0.5825084910
#   0.2717765660  0.1782516820  0.4174915090
#   0.2282234340  0.1782516820  0.9174915510
#   0.2717726470  0.6782516820  0.4174949330
#   0.2282273530  0.6782516820  0.9174949330
#   0.7717726040  0.3217482960  0.0825050620
#   0.7282273100  0.3217482960  0.5825050670
#   0.7717765660  0.8217482750  0.0825084800
#   0.7282234340  0.8217482750  0.5825084910

# %%
# (interpolation)선형 보간하는 함수 정의


# 선형 보간된 구조 lattice vector와 atom 좌표 
interpolated_structures = []

# n개의 중간 과정 만들기
n_steps = 15                           # 중간 과정 개수
for step in range(1, n_steps + 1):     #중간 과정 위치 (1부터 n_steps까지)
   

    # 보간 상수 x (중간 과정 위치 나타냄)
    # x는 곱해주는 비율(중간 과정을 3개로 만들면, 중간과정 1번 x=0.25/ 중간과정 2번 x=0.5/ 중간과정 3번 x=0.75)
    x = step / (n_steps + 1) 


    # lattice vector interpolation

    # 라티스 벡터 보간 후 중간 과정 벡터 저장할 빈 리스트
    intermediate_lattice = []

    # 3x3 라티스 벡터를 한 줄씩 지정
    for vec_initial, vec_final in zip(initial_lattice, final_lattice):

        # 좌표 하나씩 보간(interpolate)/ 보간 공식: interpol = ini + x * (fin - ini) 
        interpol_vec = [i_v + x * (f_v - i_v) for i_v, f_v in zip(vec_initial, vec_final)]

        # 중간 과정 lattice vector 저장
        intermediate_lattice.append(interpol_vec)
        

    # atom coords interpolation

    # 원자 좌표 보간 후 중간 과정 좌표 저장할 곳
    intermediate_coords = []

 # 원자 좌표를 한 줄씩 지정
    for row_initial, row_reordered in zip(initial_coords, reordered_coords):

        intermediate_coords_row =[]

        # 원자 좌표 한 개씩 지정
        for i_c, f_c in zip(row_initial, row_reordered):

            # pbc 고려해서 원자 좌표 차이 구하기
            interpol_difference = np.subtract (f_c, i_c)
            difference_round = np.round(interpol_difference)
            new_interpol_difference = interpol_difference - difference_round
        
            # 좌표 하나씩 보간(interpolate)/ 보간 공식: interpol = ini + x * (fin - ini)
            interpol_coords = i_c + x * (new_interpol_difference)

            # interpolated atom 1개 coords 저장
            intermediate_coords_row.append(interpol_coords)

        # 모든 interpolated atom의 coords 저장
        intermediate_coords.append(intermediate_coords_row)


    # 선형 보간된 구조 lattice vector와 atom 좌표로 저장
    interpolated_structures.append((intermediate_lattice, intermediate_coords))
    
print(interpolated_structures[0])
# Out:
# ([[5.60490095618125, 0.0, 0.0], [0.0, 22.52764225006875, 0.0], [0.0, 0.0, 11.1608064771125]], [[np.float64(0.19068941350000002), np.float64(0.0), np.float64(0.1172375968125)], [np.float64(0.189909699125), np.float64(0.0), np.float64(0.61723759775)], [np.float64(0.19068941350000002), np.float64(0.49999963718749996), np.float64(0.1172375968125)], [np.float64(0.189909699125), np.float64(0.49999963718749996), np.float64(0.61723759775)], [np.float64(0.6906894305), np.float64(0.0), np.float64(0.3827623825625)], [np.float64(0.689909720125), np.float64(0.0), np.float64(0.8827623799375)], [np.float64(0.6906894305), np.float64(0.5000003628124999), np.float64(0.3827623825625)], [np.float64(0.689909720125), np.float64(0.5000003628124999), np.float64(0.8827623799375)], [np.float64(0.28130333725), np.float64(0.3416807241875), np.float64(0.1148562094375)], [np.float64(0.285922213375), np.float64(0.3416807241875), np.float64(0.61485620875)], [np.float64(0.281300808), np.float64(0.8416809705625), np.float64(0.114856073875)], [np.float64(0.28591960193750005), np.float64(0.8416809705625), np.float64(0.614856073875)], [np.float64(0.7813007886875001), np.float64(0.158319049125), np.float64(0.385143896125)], [np.float64(0.7859195840000001), np.float64(0.158319049125), np.float64(0.885143896125)], [np.float64(0.7813032983125), np.float64(0.6583192758124999), np.float64(0.385143770625)], [np.float64(0.7859221716875), np.float64(0.6583192758124999), np.float64(0.885143770625)], [np.float64(0.28130333725), np.float64(0.1583192545625), np.float64(0.1148562094375)], [np.float64(0.285922213375), np.float64(0.1583192545625), np.float64(0.61485620875)], [np.float64(0.281300808), np.float64(0.6583190688125), np.float64(0.114856073875)], [np.float64(0.28591960193750005), np.float64(0.6583190688125), np.float64(0.614856073875)], [np.float64(0.7813007886875001), np.float64(0.3416809521875), np.float64(0.385143896125)], [np.float64(0.7859195840000001), np.float64(0.3416809521875), np.float64(0.885143896125)], [np.float64(0.7813032983125), np.float64(0.8416807645000001), np.float64(0.385143770625)], [np.float64(0.7859221716875), np.float64(0.8416807645000001), np.float64(0.885143770625)], [np.float64(0.2388215710625), np.float64(0.08701629225), np.float64(0.3688848698125)], [np.float64(0.2402557038125), np.float64(0.08701629225), np.float64(0.8688848671249999)], [np.float64(0.238821854625), np.float64(0.5870154648125), np.float64(0.368883307125)], [np.float64(0.240255819125), np.float64(0.5870154648125), np.float64(0.8688833098125)], [np.float64(0.738821876625), np.float64(0.412984494875), np.float64(0.13111665349999999)], [np.float64(0.740255838375), np.float64(0.412984494875), np.float64(0.6311166535)], [np.float64(0.7388216310625), np.float64(0.9129837044375), np.float64(0.13111512125)], [np.float64(0.7402557651875), np.float64(0.9129837044375), np.float64(0.631115119875)], [np.float64(0.2388215710625), np.float64(0.41298370706250004), np.float64(0.3688848698125)], [np.float64(0.2402557038125), np.float64(0.41298370706250004), np.float64(0.8688848671249999)], [np.float64(0.238821854625), np.float64(0.91298449225), np.float64(0.368883307125)], [np.float64(0.240255819125), np.float64(0.91298449225), np.float64(0.8688833098125)], [np.float64(0.738821876625), np.float64(0.0870155000625), np.float64(0.13111665349999999)], [np.float64(0.740255838375), np.float64(0.0870155000625), np.float64(0.6311166535)], [np.float64(0.7388216310625), np.float64(0.5870162955625), np.float64(0.13111512125)], [np.float64(0.7402557651875), np.float64(0.5870162955625), np.float64(0.631115119875)], [np.float64(0.2891616326875), np.float64(0.25), np.float64(0.3449630035625)], [np.float64(0.29686073481249997), np.float64(0.25), np.float64(0.8449630035625)], [np.float64(0.28916037725), np.float64(0.749999979), np.float64(0.34496512825)], [np.float64(0.296859640875), np.float64(0.749999979), np.float64(0.844965130875)], [np.float64(0.78916031725), np.float64(0.25), np.float64(0.15503487175) ...

# %%
# interpolation 파일들 저장 

# 파일 이름 설정하고 쓰기 모드로 열기
for i in range (n_steps):
    filename = f"POSCAR_interpolated_{i+1}.vasp"
    intermediate_lattice, intermediate_coords = interpolated_structures[i]
   
    with open(filename, 'w') as f:

        # 원자 이름 적기
        f.write(f"{initial_title}\n")

        # 스케일 벡터 적기
        f.write(f"{initial_scale}\n")

        # 라티스 벡터 한줄씩 적기
        for vec in intermediate_lattice:
                f.write("  " + "  ".join(f"{x:.10f}" for x in vec) + "\n")

        # 원자 종류 적기
        f.write("  " + "  ".join(initial_atom_types) + "\n")

        # 원자 종류별 갯수 적기
        f.write("  " + "  ".join(str(count) for count in initial_atom_counts) + "\n")

        # 좌표 형식 적기
        f.write(f"{initial_coord_type.capitalize()}\n")
        
        # 원자 좌표 한줄씩 적기
        for coord in intermediate_coords:
                f.write("  " + "  ".join(f"{x:.10f}" for x in coord) + "\n")

    print("저장됨:", filename)


# 저장된 'POSCAR_interpolated_1'파일 열어서 확인

filename = f"POSCAR_interpolated_{1}.vasp"
with open (filename, 'r') as f:
    content = f.read()

print(content)
# Out:
# 저장됨: POSCAR_interpolated_1.vasp
# 저장됨: POSCAR_interpolated_2.vasp
# 저장됨: POSCAR_interpolated_3.vasp
# 저장됨: POSCAR_interpolated_4.vasp
# 저장됨: POSCAR_interpolated_5.vasp
# 저장됨: POSCAR_interpolated_6.vasp
# 저장됨: POSCAR_interpolated_7.vasp
# 저장됨: POSCAR_interpolated_8.vasp
# 저장됨: POSCAR_interpolated_9.vasp
# 저장됨: POSCAR_interpolated_10.vasp
# 저장됨: POSCAR_interpolated_11.vasp
# 저장됨: POSCAR_interpolated_12.vasp
# 저장됨: POSCAR_interpolated_13.vasp
# 저장됨: POSCAR_interpolated_14.vasp
# 저장됨: POSCAR_interpolated_15.vasp
# Nd Ca Fe  O
# 1.0
#   5.6049009562  0.0000000000  0.0000000000
#   0.0000000000  22.5276422501  0.0000000000
#   0.0000000000  0.0000000000  11.1608064771
#   Nd  Ca  Fe  O
#   8  16  24  64
# Direct
#   0.1906894135  0.0000000000  0.1172375968
#   0.1899096991  0.0000000000  0.6172375977
#   0.1906894135  0.4999996372  0.1172375968
#   0.1899096991  0.4999996372  0.6172375977
#   0.6906894305  0.0000000000  0.3827623826
#   0.6899097201  0.0000000000  0.8827623799
#   0.6906894305  0.5000003628  0.3827623826
#   0.6899097201  0.5000003628  0.8827623799
#   0.2813033373  0.3416807242  0.1148562094
#   0.2859222134  0.3416807242  0.6148562088
#   0.2813008080  0.8416809706  0.1148560739
#   0.2859196019  0.8416809706  0.6148560739
#   0.7813007887  0.1583190491  0.3851438961
#   0.7859195840  0.1583190491  0.8851438961
#   0.7813032983  0.6583192758  0.3851437706
#   0.7859221717  0.6583192758  0.8851437706
#   0.2813033373  0.1583192546  0.1148562094
#   0.2859222134  0.1583192546  0.6148562088
#   0.2813008080  0.6583190688  0.1148560739
#   0.2859196019  0.6583190688  0.6148560739
#   0.7813007887  0.3416809522  0.3851438961
#   0.7859195840  0.3416809522  0.8851438961
#   0.7813032983  0.8416807645  0.3851437706
#   0.7859221717  0.8416807645  0.8851437706
#   0.2388215711  0.0870162923  0.3688848698
#   0.2402557038  0.0870162923  0.8688848671
#   0.2388218546  0.5870154648  0.3688833071
#   0.2402558191  0.5870154648  0.8688833098
#   0.7388218766  0.4129844949  0.1311166535
#   0.7402558384  0.4129844949  0.6311166535
#   0.7388216311  0.9129837044  0.1311151212
#   0.7402557652  0.9129837044  0.6311151199
#   0.2388215711  0.4129837071  0.3688848698
#   0.2402557038  0.4129837071  0.8688848671
#   0.2388218546  0.9129844923  0.3688833071
#   0.2402558191  0.9129844923  0.8688833098
#   0.7388218766  0.0870155001  0.1311166535
#   0.7402558384  0.0870155001  0.6311166535
#   0.7388216311  0.5870162956  0.1311151212
#   0.7402557652  0.5870162956  0.6311151199
#   0.2891616327  0.2500000000  0.3449630036
#   0.2968607348  0.2500000000  0.8449630036
#   0.2891603772  0.7499999790  0.3449651282
#   0.2968596409  0.7499999790  0.8449651309
#   0.7891603173  0.2500000000  0.1550348717
#   0.7968595809  0.2500000000  0.6550348691
#   0.7891615933  0.7499999790  0.1550369971
#   0.7968606954  0.7499999790  0.6550369991
#   0.0285665631  0.3979465981  0.2289665312
#   0.0321284031  0.3979466219  0.7278657941
#   0.0285651340  0.8979467016  0.2289663939
#   0.0321269766  0.8979466804  0.7278656522
#   0.0285665631  0.1020534203  0.2289665312
#   0.0321284031  0.1020533985  0.7278657941
#   0.0285651340  0.6020531768  0.2289663939
#   0.0321269766  0.6020531953  0.7278656522
#   0.5285651171  0.1020532691  0.2710336074
#   0.5321269573  0.1020532909  0.7721343478
#   0.5285665509  0.6020533143  0.2710334469
#   0.5321283884  0.6020532958  0.7721341916
#   0.5285651171  0.3979467409  0.2710336074
#   0.5321269573  0.3979467171  0.7721343478
#   0.5285665509  0.8979466007  0.2710334469
#   0.5321283884  0.8979466219  0.7721341916
#   0.9520600188  0.0697660774  0.4821903343
#   0.9520600188  0.0698185277  0.9821903316
#   0.9520616922  0.5697660994  0.4821892895
#   0.9520616922  0.5698185474  0.9821892891
#   0.9520600188  0.4302339032  0.4821903343
#   0.9520600188  0.4301814526  0.9821903316
#   0.9520616922  0.9302339006  0.4821892895
#   0.9520616922  0.9301814500  0.9821892891
#   0.4520617154  0.4302338629  0.0178107463
#   0.4520617881  0.4301814123  0.5178107499
#   0.4520600742  0.9302339006  0.0178096481
#   0.4520600043  0.9301814500  0.5178096479
#   0.4520617154  0.0697661318  0.0178107463
#   0.4520617881  0.0698185821  0.5178107499
#   0.4520600742  0.5697660994  0.0178096481
#   0.4520600043  0.5698185474  0.5178096479
#   0.1186395722  0.2500000000  0.1970340411
#   0.1384428063  0.2500000000  0.6893431548
#   0.1186406697  0.7499999790  0.1970353194
#   0.1384439037  0.7499999790  0.6893444331
#   0.6186406787  0.2500000000  0.3029646819
#   0.6384439154  0.2500000000  0.8106555695
#   0.6186395906  0.7499999790  0.3029659602
#   0.6384428274  0.7499999790  0.8106568478
#   0.2638368770  0.0000000000  0.3263983221
#   0.2659998068  0.0000000000  0.8263983207
#   0.2638368770  0.5000000553  0.3263983221
#   0.2659998068  0.5000000553  0.8263983207
#   0.7638368573  0.0000000000  0.1736016896
#   0.7659997871  0.0000000000  0.6736016869
#   0.7638368573  0.4999999868  0.1736016896
#   0.7659997871  0.4999999868  0.6736016869
#   0.2058561457  0.3214808455  0.4174862337
#   0.2031340749  0.3214808455  0.9174862363
#   0.2058546661  0.8214811606  0.4174865274
#   0.2031330852  0.8214811606  0.9174865274
#   0.7058546427  0.1785188170  0.0825134564
#   0.7031330619  0.1785188170  0.5825134576
#   0.7058561260  0.6785191142  0.0825137703
#   0.7031340553  0.6785191142  0.5825137710
#   0.2058561457  0.1785191545  0.4174862337
#   0.2031340749  0.1785191545  0.9174862363
#   0.2058546661  0.6785188367  0.4174865274
#   0.2031330852  0.6785188367  0.9174865274
#   0.7058546427  0.3214811816  0.0825134564
#   0.7031330619  0.3214811816  0.5825134576
#   0.7058561260  0.8214808428  0.0825137703
#   0.7031340553  0.8214808428  0.5825137710
